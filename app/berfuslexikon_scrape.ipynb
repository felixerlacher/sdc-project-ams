# %% [markdown]
# # Scrape Berufslexikon
#
# Scrape https://www.berufslexikon.at/berufe/ for all professions & href links and save them in a json file.
#
# 1 of error, but no problem, since all professions are scraped.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException
import random
import time

# Initialize an empty dictionary
professions = {}

# Setup Firefox options
firefox_options = Options()
firefox_options.add_argument("--headless")  # Ensure GUI is off


# Choose Firefox Browser
driver = webdriver.Firefox(executable_path=r'C:\Tools\GeckoDriver\geckodriver.exe')

url = "https://www.berufslexikon.at/berufe/"
driver.get(url)

# Wait for the page to fully load
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "table")))

# Try to accept cookies
try:
    accept_cookies_button = driver.find_element_by_id('btCookieConsentButtonAllowAll')
    accept_cookies_button.click()
except NoSuchElementException:
    pass  # If the button is not found, just ignore

# Wait for the page to fully load
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "table")))

# Try to select 100 from the dropdown
try:
    select = Select(driver.find_element_by_name('list-table_length'))
    select.select_by_value('100')
except NoSuchElementException:
    print("Could not find dropdown or value 100")

# Loop through each page
for i in range(0, 18):  # 18 pages
    # Randomize wait time between requests
    ran = random.randint(1, 5)/100

    # Wait until the processing panel is not visible
    try:
        WebDriverWait(driver, 10).until(EC.invisibility_of_element_located((By.ID, "list-table_processing")))
    except TimeoutException:
        print("Timed out waiting for processing panel to disappear.")
        continue  # Skip this iteration and try the next page

    # Try to find the page button
    try:
        
        #page_btn = driver.find_element_by_css_selector(f'a[aria-controls="list-table"][data-dt-idx="{i}"]')
        #<a href="#" aria-controls="list-table" data-dt-idx="8" tabindex="0">Vor</a>
        page_btn = driver.find_element_by_css_selector(f'a[aria-controls="list-table"][data-dt-idx="8"]')
    except Exception as e:
        print("did not find page button")
        break  # If we can't find it, we're on the last page

    # # Scroll the page button into view
    # driver.execute_script("arguments[0].scrollIntoView();", page_btn)

    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(ran)

    # Click the page button and wait for the page to load
    page_btn.click()
    WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "table")))

    # Parse the page
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    rows = soup.findAll('table')[0].findAll('tr')
    for row in rows:
        links = row.select('a[href^="/berufe"]')
        for link in links:
            print(link['href'], link.text)
            # Store in format {name: link}
            professions[link.text] = link['href']

driver.quit()
# Out:
# /berufe/3045-24-Stunden-BetreuerIn/ 24-Stunden-BetreuerIn
# /berufe/3049-3D-DesignerIn/ 3D-DesignerIn
# /berufe/3866-AbfallbeauftragteR/ AbfallbeauftragteR
# /berufe/3200-AbfallberaterIn/ AbfallberaterIn
# /berufe/2147-AbfallwirtschaftstechnikerIn/ AbfallwirtschaftstechnikerIn
# /berufe/3696-AbnahmetechnikerIn/ AbnahmetechnikerIn
# /berufe/3818-Entsorgungsfachkraft_fuer_Abwassertechnik/ AbwassertechnikerIn
# /berufe/2814-Aerobic-TrainerIn/ Aerobic-TrainerIn
# /berufe/2963-AfrikanistIn/ AfrikanistIn
# /berufe/1934-AgrarberaterIn/ AgrarberaterIn
# /berufe/2987-Agrarbiologe~Agrarbiologin/ Agrarbiologe/-biologin
# /berufe/1935-Agrarkaufmann~Agrarkauffrau/ Agrarkaufmann/Agrarkauffrau
# /berufe/3835-AgrarmanagerIn/ AgrarmanagerIn
# /berufe/2593-AgraroekonomIn/ AgrarökonomIn
# /berufe/2297-Aegyptologe~Aegyptologin/ Ägyptologe/Ägyptologin
# /berufe/2468-AktuarIn/ AktuarIn
# /berufe/3050-AkustikerIn/ AkustikerIn
# /berufe/3051-AkustikphysikerIn/ AkustikphysikerIn
# /berufe/2298-AltsemitischeR-Philologe~Philologin-OrientalistischeR-Archaeologe~Archaeologin/ Altsemitischer Philologe/Philologin
# /berufe/3219-AltwarenhaendlerIn/ AltwarenhändlerIn
# /berufe/3332-AmtlicheR-FachassistentIn-Schlachttieruntersuchung-Fleischuntersuchung/ AmtlicheR FachassistentIn bei der Schlachttier- und Fleischuntersuchung
# /berufe/1648-AnalystIn/ AnalystIn
# /berufe/3690-AenderungsschneiderIn/ ÄnderungsschneiderIn
# /berufe/2299-AnglistIn-AmerikanistIn/ AnglistIn, AmerikanistIn
# /berufe/2773-AnimateurIn/ AnimateurIn
# /berufe/3703-AnimationsdesignerIn/ AnimationsdesignerIn
# /berufe/1646-AnlagenberaterIn/ AnlageberaterIn
# /berufe/3011-AnlageberaterIn/ AnlageberaterIn
# /berufe/1973-AnlagenbautechnikerIn/ AnlagenbautechnikerIn
# /berufe/1830-AntriebstechnikerIn/ AntriebstechnikerIn
# /berufe/3116-Anwalt~Anwaeltin_Arbeitsrecht/ Anwalt/Anwältin - Schwerpunkt Arbeitsrecht
# /berufe/2527-Anwalt~Anwaeltin-Bankrecht-Finanzierung/ Anwalt/Anwältin - Schwerpunkt Bankrecht und Finanzierung
# /berufe/2522-Anwalt~Anwltin-Europarecht/ Anwalt/Anwältin - Schwerpunkt Europarecht
# /berufe/2524-Anwalt~Anwaeltin-Internationales-Recht/ Anwalt/Anwältin - Schwerpunkt Internationales Recht
# /berufe/2525-Anwalt~Anwaeltin-Wirtschaftsrecht/ Anwalt/Anwältin - Schwerpunkt Wirtschaftsrecht
# /berufe/3649-AnwendungsbetreuerIn/ AnwendungsbetreuerIn
# /berufe/2581-AnwendungstechnikerIn/ AnwendungstechnikerIn
# /berufe/2166-AnzeigenverkaeuferIn/ AnzeigenverkäuferIn
# /berufe/2838-AnzeigenverkaeuferIn/ AnzeigenverkäuferIn
# /berufe/2478-ApothekerIn/ ApothekerIn
# /berufe/3276-App-Developer/ App-DeveloperIn
# /berufe/1797-ApparatebautechnikerIn/ ApparatebautechnikerIn
# /berufe/3500-Applikationsentwicklung-Coding/ ApplikationsentwicklerIn - Coding
# /berufe/2300-ArabistIn/ ArabistIn
# /berufe/3052-Arbeits-und-Organisationpsychologe~Arbeits-und-Organisationpsychologin/ Arbeits- und Organisationspsychologe/Arbeits- und Organisationspsychologin
# /berufe/3782-ArbeitsmedizinischeR_AssistentIn/ ArbeitsmedizinischeR AssistentIn
# /berufe/2095-ArbeitstechnikerIn/ ArbeitstechnikerIn
# /berufe/2096-ArbeitsvorbereiterIn/ ArbeitsvorbereiterIn
# /berufe/2222-Archaeologe~Archaeologin/ Archäologe/Archäologin
# /berufe/2224-Archaeologe~Archaeologin-Mykenologie/ Archäologe/Archäologin - Mykenologie
# /berufe/2223-Archaeologe~Archaeologin-Urgeschichte-Fruehgeschichte/ Archäologe/Archäologin - Ur- und Frühgeschichte
# /berufe/2321-ArchitektIn/ ArchitektIn
# /berufe/263-ArchivassistentIn-BibliotheksassistentIn-InformationsassistentIn/ Archiv-, Bibliotheks- und InformationsassistentIn
# /berufe/2839-ArchivarbeiterIn/ ArchivarbeiterIn
# /berufe/2446-ArchivarIn/ ArchivarIn
# /berufe/2502-Area-ManagerIn/ Area ManagerIn
# /berufe/3053-Art-Buyer/ Art Buyer (m/w)
# /berufe/2352-Art-Director/ Art Director
# /berufe/2177-Creative-Director/ Art Director (m/w)
# /berufe/2928-ArtistIn/ ArtistIn
# /berufe/2383-Arzt~Aerztin-Allgemeinmedizin/ Arzt/Ärztin für Allgemeinmedizin
# /berufe/2757-AsphaltiererIn/ AsphaltiererIn
# /berufe/3537-AssistentIn_in_der_Sicherheitsverwaltung/ AssistentIn in der Sicherheitsverwaltung
# /berufe/2609-AstronomIn/ AstronomIn
# /berufe/2613-AstrophysikerIn/ AstrophysikerIn
# /berufe/3009-AtomphysikerIn/ AtomphysikerIn
# /berufe/3534-AuditorIn/ AuditorIn
# /berufe/3054-AufnahmeleiterIn/ AufnahmeleiterIn
# /berufe/1689-AuftragssachbearbeiterIn/ AuftragssachbearbeiterIn
# /berufe/152-AugenoptikerIn/ AugenoptikerIn
# /berufe/2929-AuktionatorIn/ AuktionatorIn
# /berufe/2960-AuslandskorrespondentIn/ AuslandskorrespondentIn
# /berufe/3629-AutobusfahrerIn/ AutobusfahrerIn
# /berufe/1641-AutomatisierungstechnikerIn/ AutomatisierungstechnikerIn
# /berufe/2669-AutomatisierungstechnikerIn/ AutomatisierungstechnikerIn
# /berufe/3667-Automotive-Computing-Engineer-%28m-w%29/ Automotive Computing Engineer (m/w)
# /berufe/3689-Automotive_Mechatronics_Engineer/ Automotive Mechatronics Engineer (m/w)
# /berufe/3220-AutorIn/ AutorIn
# /berufe/2-BaeckerIn/ BäckerIn
# /berufe/3507-Backtechnologe~Backtechnologin/ Backtechnologe/-technologin
# /berufe/3255-BadewaerterIn/ BadewärterIn
# /berufe/2933-BahnarbeiterIn-GleisarbeiterIn/ Bahn- und GleisarbeiterIn
# /berufe/3056-BallettmeisterIn/ BallettmeisterIn
# /berufe/1649-BankangestellteR_-_Back-Office/ BankangestellteR - Back-Office
# /berufe/1653-BankangestellteR_-_Front-Office/ BankangestellteR - Front-Office
# /berufe/1647-BankangestellteR_-_internationales_Bankwesen/ BankangestellteR - internationales Bankwesen
# /berufe/1863-BankettmanagerIn/ BankettmanagerIn
# /berufe/3-Bankkaufmann~Bankkauffrau/ Bankkaufmann/-frau
# /berufe/1650-Bankkaufmann~Bankkauffrau/ Bankkaufmann/-frau
# /berufe/3013-BankrevisorIn/ BankrevisorIn
# /berufe/3314-Barista/ Barista (m/w)
# /berufe/2774-BarmixerIn/ BarmixerIn
# /berufe/1680-BauabrechnungstechnikerIn/ BauabrechnungstechnikerIn
# /berufe/3057-Baubiologe~Baubiologin/ Baubiologe/-biologin
# /berufe/3621-BauhelferIn/ BauhelferIn
# /berufe/2986-BauinformatikerIn/ BauinformatikerIn
# /berufe/3344-BauingenieurIn-Kraftwerksbau/ BauingenieurIn - Kraftwerksbau
# /berufe/3345-BauingenieurIn-Spezialtiefbau/ BauingenieurIn - Spezialtiefbau
# /berufe/2699-BauingenieurIn-Bergbau/ BauingenieurIn im Bergbau
# /berufe/1661-Baukaufmann~Baukauffrau/ Baukaufmann/-frau
# /berufe/3814-BauleiterIn/ BauleiterIn
# /berufe/1667-BauleiterIn/ BauleiterIn
# /berufe/2758-BaumaschinistIn/ BaumaschinistIn
# /berufe/3802-BaumeisterIn/ BaumeisterIn
# /berufe/3557-BaumpflegerIn/ BaumpflegerIn
# /berufe/1859-BaumschulgaertnerIn/ BaumschulgärtnerIn
# /berufe/3622-BaupolierIn/ BaupolierIn
# /berufe/3589-BauspenglerIn/ BauspenglerIn
# /berufe/3058-BaustatikerIn/ BaustatikerIn
# /berufe/3593-BaustatikerIn/ BaustatikerIn
# /berufe/3594-BaustellenkoordinatorIn/ BaustellenkoordinatorIn
# /berufe/1669-BaustofftechnikerIn/ BaustofftechnikerIn
# /berufe/3060-BaustofftechnikerIn/ BaustofftechnikerIn
# /berufe/1663-BautechnikerIn/ BautechnikerIn
# /berufe/2540-BautechnikerIn/ BautechnikerIn
# /berufe/2538-BautechnikerIn-Bauphysik/ BautechnikerIn - Bauphysik
# /berufe/2536-BautechnikerIn-Hochbau/ BautechnikerIn - Hochbau
# /berufe/2537-BautechnikerIn-Sanierungstechnik/ BautechnikerIn für Sanierungstechnik
# /berufe/3488-BauechnischeR_AssistentIn/ Bautechnisch(er/e) AssistentIn
# /berufe/5-BautechnischeR-ZeichnerIn/ Bautechnisch(er/e) ZeichnerIn
# /berufe/1666-BautechnischeR_ZeichnerIn/ BautechnischeR ZeichnerIn
# /berufe/3508-BauwerksabdichtungstechnikerIn/ BauwerksabdichtungstechnikerIn
# /berufe/2893-Beamter~Beamte-im-Kriminaldienst/ Beamter/Beamtin im Kriminaldienst
# /berufe/6-BekleidungsfertigerIn/ BekleidungsfertigerIn
# /berufe/3382-BekleidungsgestalterIn-Hauptmodul_Damenbekleidung/ BekleidungsgestalterIn - Hauptmodul Damenbekleidung
# /berufe/3383-BekleidungsgestalterIn-Hauptmodul_Herrenbekleidung/ BekleidungsgestalterIn - Hauptmodul Herrenbekleidung
# /berufe/3384-BekleidungsgestalterIn-Hauptmodul_KuerschnerIn_und_SaecklerIn/ BekleidungsgestalterIn - Hauptmodul KürschnerIn und SäcklerIn
# /berufe/3385-BekleidungsgestalterIn-Hauptmodul_ModistIn_und_HutmacherIn/ BekleidungsgestalterIn - Hauptmodul ModistIn und HutmacherIn
# /berufe/3386-BekleidungsgestalterIn-Hauptmodul_Waeschewarenerzeugung/ BekleidungsgestalterIn - Hauptmodul Wäschewarenerzeugung
# /berufe/2123-BekleidungstechnikerIn/ BekleidungstechnikerIn
# /berufe/3061-BekleidungstechnikerIn/ BekleidungstechnikerIn
# /berufe/2099-BetriebstechnikerIn/ BetriebstechnikerIn
# /berufe/2563-BetriebswirtIn/ BetriebswirtIn
# /berufe/3016-BetriebswirtIn-Ernaehrungsmanagement-Versorgungsmanagement/ BetriebswirtIn im Bereich Ernährungs- und Versorgungsmanagement
# /berufe/3780-BetrugsbekaempferIn/ BetrugsbekämpferIn
# /berufe/2075-BewaehrungshelferIn/ BewährungshelferIn
# /berufe/2969-BewegungstherapeutIn/ BewegungstherapeutIn
# /berufe/2447-BibliothekarIn/ BibliothekarIn
# /berufe/2840-BibliothekarIn/ BibliothekarIn
# /berufe/3721-Bid-ManagerIn/ Bid-ManagerIn
# /berufe/3757-Bid_ManagerIn/ Bid-ManagerIn
# /berufe/3792-BikeGuide/ Bike Guide (m/w)
# /berufe/91-BildhauerIn/ BildhauerIn
# /berufe/1768-BildhauerIn/ BildhauerIn
# /berufe/2323-BildhauerIn/ BildhauerIn
# /berufe/3063-BildmischerIn/ BildmischerIn
# /berufe/3064-BildtechnikerIn/ BildtechnikerIn
# /berufe/3065-BildungsforscherIn/ BildungsforscherIn
# /berufe/3353-BildungsmanagerIn/ BildungsmanagerIn
# /berufe/2841-BilleteurIn/ BilleteurIn
# /berufe/3796-BIMPractitioner/ BIM Practitioner (m/w)
# /berufe/3797-BIM-ModelliererIn/ BIM-ModelliererIn
# /berufe/3798-BIM-ProjektmanagerIn/ BIM-ProjektmanagerIn
# /berufe/3804-BIM-ProjektmanagerIn/ BIM-ProjektmanagerIn
# /berufe/1946-Biobauer~Biobaeuerin/ Biobauer/-bäuerin
# /berufe/1729-BiochemikerIn/ BiochemikerIn
# /berufe/2439-BioinformatikerIn/ BioinformatikerIn
# /berufe/2597-Biologe~Biologin/ Biologe/Biologin
# /berufe/2453-BiomedizinischeR-AnalytikerIn/ BiomedizinischeR AnalytikerIn
# /berufe/2995-BionikerIn/ BionikerIn
# /berufe/3066-BiophysikerIn/ BiophysikerIn
# /berufe/2618-BiostatistikerIn/ BiostatistikerIn
# /berufe/2626-Biotechnologe~Biotechnologin/ Biotechnologe/-technologin
# /berufe/3596-Biotechnologe~Biotechnologin/ Biotechnologe/-technologin
# /berufe/2655-BioverfahrenstechnikerIn/ BioverfahrenstechnikerIn
# /berufe/15-BlechblasinstrumentenerzeugerIn/ BlechblasinstrumentenerzeugerIn
# /berufe/3556-BloggerIn/ BloggerIn
# /berufe/18-BodenlegerIn/ BodenlegerIn
# /berufe/2888-Bodyguard/ Bodyguard (m/w)
# /berufe/2759-BohrarbeiterIn/ BohrarbeiterIn
# /berufe/1852-Boot-und-SchiffbautechnikerIn/ Boot- und SchiffbauerIn
# /berufe/20-BootbauerIn/ BootbauerIn
# /berufe/2896-BordtechnikerIn/ BordtechnikerIn
# /berufe/3012-BoersenhaendlerIn/ BörsenhändlerIn
# /berufe/2598-BotanikerIn/ BotanikerIn
# /berufe/21-BrautechnikerIn-GetraenketechnikerIn/ Brau- und GetränketechnikerIn
# /berufe/2897-Brief-undPaketzustellerIn/ Brief- und PaketzustellerIn
# /berufe/22-BrunnenbauerIn-GrundbauerIn/ Brunnen- und GrundbauerIn
# /berufe/258-BuchwirtschafterIn-MedienwirtschafterIn-Buchhandel-Musikalienhandel/ Buch- und MedienwirtschafterIn - Buch- und Musikalienhandel
# /berufe/259-BuchwirtschafterIn-MedienwirtschafterIn-Buchgrosshandel-Pressegrosshandel/ Buch- und MedienwirtschafterIn - Buch- und Pressegroßhandel
# /berufe/260-BuchwirtschafterIn-MedienwirtschafterIn-Verlag/ Buch- und MedienwirtschafterIn - Verlag
# /berufe/3582-BuchbindetechnikerIn_und_Postpresstechnologe_Postpresstechnologin-Schwerpunkt_BuchbinderIn/ BuchbindetechnikerIn und Postpresstechnologe/-technologin - Schwerpunkt Buchbinder/Buchbinderin
# /berufe/3583-BuchbindetechnikerIn_und_Postpresstechnologe_Postpresstechnologin-Schwerpunkt_Buchfertigungstechnik/ BuchbindetechnikerIn und Postpresstechnologe/-technologin - Schwerpunkt Buchfertigungstechnik
# /berufe/3584-BuchbindetechnikerIn_und_Postpresstechnologe_Postpresstechnologin-Schwerpunkt_Postpresstechnologie/ BuchbindetechnikerIn und Postpresstechnologe/-technologin - Schwerpunkt Postpresstechnologie
# /berufe/1747-BuchhalterIn/ BuchhalterIn
# /berufe/24-BuechsenmacherIn/ BüchsenmacherIn
# /berufe/2776-Buffetkraft-Schankkraft/ Buffet- und Schankkraft (m/w)
# /berufe/2842-BuehnenarbeiterIn/ BühnenarbeiterIn
# /berufe/2344-BuehnenbildnerIn/ BühnenbildnerIn
# /berufe/3067-BuehnentechnikerIn/ BühnentechnikerIn
# /berufe/2768-BuerogehilfIn/ BürogehilfIn
# /berufe/25-Buerokaufmann~Buerokauffrau/ Bürokaufmann/-frau
# /berufe/2500-Business-Development-ManagerIn/ Business Development ManagerIn
# /berufe/2573-Business-AnalystIn/ Business-AnalystIn
# /berufe/3588-ButlerIn/ ButlerIn
# /berufe/2301-ByzantinistIn-NeograezistIn/ ByzantinistIn, NeogräzistIn
# /berufe/3068-CAD-KonstrukteurIn/ CAD-KonstrukteurIn
# /berufe/3688-CAD-KonstrukteurIn-Fahrzeugbau/ CAD-KonstrukteurIn im Fahrzeugbau
# /berufe/1925-CAD-TechnikerIn/ CAD-TechnikerIn
# /berufe/3695-CAD-TechnikerIn/ CAD-TechnikerIn
# /berufe/1926-CAD-TechnikerIn-Elektronik/ CAD-TechnikerIn für Elektronik
# /berufe/1723-Callcenter_Agent/ Callcenter Agent (m/w)
# /berufe/2803-Callcenter-Agent/ Callcenter Agent (m/w)
# /berufe/2055-CAM-TechnikerIn/ CAM-TechnikerIn
# /berufe/3221-CampingplatzwartIn/ CampingplatzwartIn
# /berufe/3759-Category_ManagerIn/ Category-ManagerIn
# /berufe/3760-Category_ManagerIn/ Category-ManagerIn
# /berufe/1864-Catering-ManagerIn/ Catering-ManagerIn
# /berufe/3771-CateringmitarbeiterIn/ Catering-MitarbeiterIn
# /berufe/2499-ManagerIn-Change-Management/ Change ManagerIn
# /berufe/30-DachdeckerIn/ DachdeckerIn
# /berufe/3076-DaF-LektorIn/ DaF-LektorIn
# /berufe/3852-DataScientist/ Data Scientist (m/w)
# /berufe/3002-Data-Warehouse-AnalystIn/ Data Warehouse AnalystIn
# /berufe/3645-Data-Warehouse-ManagerIn/ Data-Warehouse-ManagerIn
# /berufe/1762-DatenbankadministratorIn/ DatenbankadministratorIn
# /berufe/2748-DatenbankadministratorIn/ DatenbankadministratorIn
# /berufe/1763-DatenbankentwicklerIn/ DatenbankentwicklerIn
# /berufe/2747-DatenbankentwicklerIn/ DatenbankentwicklerIn
# /berufe/3349-DatenschutzbeauftragteR/ DatenschutzbeauftragteR
# /berufe/3644-Datensicherheitsexperte~Datensicherheitsexpertin/ Datensicherheitsexperte/-expertin
# /berufe/2749-Datensicherheitsexperte/ Datensicherheitsexperte/Datensicherheitsexpertin
# /berufe/2804-DekorateurIn/ DekorateurIn
# /berufe/3077-DenkmalpflegerIn/ DenkmalpflegerIn
# /berufe/2919-DeponiewartIn/ DeponiewartIn
# /berufe/3532-DeponiewartIn/ DeponiewartIn
# /berufe/2329-DesignerIn/ DesignerIn
# /berufe/3747-DesinfektionsassistentIn/ DesinfektionsassistentIn
# /berufe/3320-DesinfektionsassistentIn/ DesinfektionsassistentIn
# /berufe/34-DestillateurIn/ DestillateurIn
# /berufe/2886-DetektivIn/ DetektivIn
# /berufe/3651-DevOps-Engineer-%28m-w%29/ DevOps Engineer (m/w)
# /berufe/2977-Diaetologe~Diaetologin/ Diätologe/Diätologin
# /berufe/1907-DigitaltechnikerIn-IT/ DigitaltechnikerIn IT
# /berufe/3506-Gesundheits-KrankenpflegerIn/ Dipl. Gesundheits- und KrankenpflegerIn
# /berufe/3739-Dipl.Gesundheits-undKrankenpflegerIn-Ansthesiepflege/ Dipl. Gesundheits- und KrankenpflegerIn - Anästhesiepflege
# /berufe/3744-Dipl.Gesundheits-undKrankenpflegerIn-Hospiz-undPalliativversorgung/ Dipl. Gesundheits- und KrankenpflegerIn - Hospiz- und Palliativversorgung
# /berufe/3738-Dipl.Gesundheits-undKrankenpflegerIn-Intensivpflege/ Dipl. Gesundheits- und KrankenpflegerIn - Intensivpflege
# /berufe/3735-Dipl.Gesundheits-undKrankenpflegerIn-Kinder-undJugendlichenpflege/ Dipl. Gesundheits- und KrankenpflegerIn - Kinder- und Jugendlichenpflege
# /berufe/3741-Dipl.Gesundheits-undKrankenpflegerIn-Kinderintensivpflege/ Dipl. Gesundheits- und KrankenpflegerIn - Kinderintensivpflege
# /berufe/3742-Dipl.Gesundheits-undKrankenpflegerIn-Krankenhaushygiene/ Dipl. Gesundheits- und KrankenpflegerIn - Krankenhaushygiene
# /berufe/3737-Dipl.Gesundheits-undKrankenpflegerIn-PflegebeiNierenersatztherapie/ Dipl. Gesundheits- und KrankenpflegerIn - Pflege bei Nierenersatztherapie
# /berufe/3740-Dipl.Gesundheits-undKrankenpflegerIn-PflegeimOperationsbereich/ Dipl. Gesundheits- und KrankenpflegerIn - Pflege im Operationsbereich
# /berufe/3736-Dipl.Gesundheits-undKrankenpflegerIn-PsychiatrischeGesundheits-undKrankenpflege/ Dipl. Gesundheits- und KrankenpflegerIn - Psychiatrische Gesundheits- und Krankenpflege
# /berufe/3745-Dipl.Gesundheits-undKrankenpflegerIn-PsychogeriatrischePflege/ Dipl. Gesundheits- und KrankenpflegerIn - Psychogeriatrische Pflege
# /berufe/3743-Dipl.Gesundheits-undKrankenpflegerIn-WundmanagementundStomaversorgung/ Dipl. Gesundheits- und KrankenpflegerIn - Wundmanagement und Stomaversorgung
# /berufe/3299-KardiotechnikerIn/ Dipl. KardiotechnikerIn
# /berufe/3046-Diplom-SozialbetreuerIn_fuer_Altenarbeit/ Diplom-SozialbetreuerIn für Altenarbeit
# /berufe/3047-Diplom-SozialbetreuerIn-Behindertenarbeit-und-Behindertenbegleitung/ Diplom-SozialbetreuerIn für Behindertenarbeit und Behindertenbegleitung
# /berufe/3048-Diplom-SozialbetreuerIn-Familienarbeit/ Diplom-SozialbetreuerIn für Familienarbeit
# /berufe/2229-DiplomatikerIn/ DiplomatikerIn
# /berufe/2488-DiplomatIn/ DiplomatIn
# /berufe/1879-DiplomierteR_Gesundheits-_und_KrankenpflegerIn/ DiplomierteR Gesundheits- und KrankenpflegerIn
# /berufe/1880-DiplomierteR_Gesundheits-_und_KrankenpflegerIn_Kinder-_und_Jugendlichenpflege/ DiplomierteR Gesundheits- und KrankenpflegerIn - Kinder- und Jugendlichenpflege
# /berufe/1881-DiplomierteR_Gesundheits-_und_KrankenpflegerIn_Psychiatrische_Gesundheits-_und_Krankenpflege/ DiplomierteR Gesundheits- und KrankenpflegerIn - Psychiatrische Gesundheits- und Krankenpflege
# /berufe/3323-DiplomierteR-medizinischeR-FachassistentIn-MFA/ DiplomierteR medizinischeR FachassistentIn (MFA)
# /berufe/3808-OperationstechnischeRAssistentIn/ DiplomierteR OperationstechnischeR AssistentIn (OTA)
# /berufe/1872-DirektionsassistentIn/ DirektionsassistentIn
# /berufe/3079-Direktmarketing-ManagerIn/ Direktmarketing ManagerIn
# /berufe/2375-DirigentIn/ DirigentIn
# /berufe/2931-Disc-Jockey/ Disc-Jockey (m/w)
# /berufe/1950-DisponentIn/ DisponentIn
# /berufe/2448-DokumentarIn/ DokumentarIn
# /berufe/2843-DokumentarIn/ DokumentarIn
# /berufe/2287-DolmetscherIn/ DolmetscherIn
# /berufe/2539-DomotronikerIn/ DomotronikerIn
# /berufe/2863-DorfhelferIn-in-der-Landwirtschaft/ DorfhelferIn in der Landwirtschaft
# /berufe/2778-DrachenfluglehrerIn-ParagleiterlehrerIn/ Drachenflug- und ParagleiterlehrerIn
# /berufe/2361-DramaturgIn/ DramaturgIn
# /berufe/2362-DrehbuchautorIn/ DrehbuchautorIn
# /berufe/1637-DrogistIn/ DrogistIn
# /berufe/3714-DrohnenpilotIn/ DrohnenpilotIn
# /berufe/1777-DrucktechnikerIn/ DrucktechnikerIn
# /berufe/2891-PolizistIn/ ExekutivbediensteteR im Polizeidienst
# /berufe/3007-ExperimentalphysikerIn/ ExperimentalphysikerIn
# /berufe/2495-ExportmanagerIn/ ExportmanagerIn
# /berufe/1951-ExportsachbearbeiterIn/ ExportsachbearbeiterIn
# /berufe/3536-Fach-SozialbetreuerIn_Altenarbeit/ Fach-SozialbetreuerIn für Altenarbeit
# /berufe/3617-Fach-SozialbetreuerIn_Altenarbeit/ Fach-SozialbetreuerIn für Altenarbeit
# /berufe/3551-Fach-SozialbetreuerIn_Behindertenarbeit-Behindertenbegleitung/ Fach-SozialbetreuerIn für Behindertenarbeit und Behindertenbegleitung
# /berufe/3618-Fach-SozialbetreuerIn_Behindertenarbeit-Behindertenbegleitung/ Fach-SozialbetreuerIn für Behindertenarbeit und Behindertenbegleitung
# /berufe/12-FacharbeiterIn-Bienenwirtschaft/ FacharbeiterIn Bienenwirtschaft
# /berufe/3036-FacharbeiterIn-Biomasseproduktion-und-landwirtschaftliche-Bioenergiegewinnung/ FacharbeiterIn Biomasseproduktion und landwirtschaftliche Bioenergiegewinnung
# /berufe/56-FacharbeiterIn-Feldgemuesebau/ FacharbeiterIn Feldgemüsebau
# /berufe/59-FacharbeiterIn-Fischereiwirtschaft/ FacharbeiterIn Fischereiwirtschaft
# /berufe/64-FacharbeiterIn-Forstgartenwirtschaft-Forstpflegewirtschaft/ FacharbeiterIn Forstgarten- und Forstpflegewirtschaft
# /berufe/63-FacharbeiterIn-Forstwirtschaft/ FacharbeiterIn Forstwirtschaft
# /berufe/71-FacharbeiterIn-Gartenbau/ FacharbeiterIn Gartenbau
# /berufe/73-FacharbeiterIn-Gefluegelwirtschaft/ FacharbeiterIn Geflügelwirtschaft
# /berufe/52-FacharbeiterIn-laendliches-Betriebsmanagement-Haushaltsmanagement/ FacharbeiterIn ländliches Betriebs- und Haushaltsmanagement
# /berufe/127-FacharbeiterIn-Landwirtschaft/ FacharbeiterIn Landwirtschaft
# /berufe/53-FacharbeiterIn-landwirtschaftliche-Lagerhaltung/ FacharbeiterIn landwirtschaftliche Lagerhaltung
# /berufe/147-FacharbeiterIn-Molkereiwirtschaft-Kaesereiwirtschaft/ FacharbeiterIn Molkerei- und Käsereiwirtschaft
# /berufe/151-FacharbeiterIn-Obstbau-Obstverwertung/ FacharbeiterIn Obstbau und Obstverwertung
# /berufe/156-FacharbeiterIn-Pferdewirtschaft/ FacharbeiterIn Pferdewirtschaft
# /berufe/225-FacharbeiterIn-Weinbau-Kellerwirtschaft/ FacharbeiterIn Weinbau und Kellerwirtschaft
# /berufe/3683-Facharzt-aerztin/ Facharzt/-ärztin
# /berufe/2389-Facharzt-aerztin-fuer-Allgemeinchirurgie-und-Viszeralchirurgie/ Facharzt/-ärztin für Allgemeinchirurgie und Viszeralchirurgie
# /berufe/2384-Facharzt-aerztin-fuer-Ansthesiologie-und-Intensivmedizin/ Facharzt/-ärztin für Anästhesiologie und Intensivmedizin
# /berufe/2056-FertigungstechnikerIn/ FertigungstechnikerIn
# /berufe/3250-TaucherIn/ FeuerwehrtaucherIn
# /berufe/2899-FiakerIn/ FiakerIn
# /berufe/2347-FilmarchitektIn/ FilmarchitektIn
# /berufe/2966-FilmausstatterIn/ FilmausstatterIn
# /berufe/2350-FilmeditorIn/ FilmeditorIn
# /berufe/3603-FilmeditorIn/ FilmeditorIn
# /berufe/2844-FilmvorfuehrerIn/ FilmvorführerIn
# /berufe/3334-FilmwissenschafterIn/ FilmwissenschafterIn
# /berufe/1702-FinanzberaterIn-AnlagenberaterIn/ Finanz- und AnlageberaterIn
# /berufe/3315-FinanzassistentIn-RechnungswesenassistentIn/ Finanz- und RechnungswesenassistentIn
# /berufe/2924-Finanzdienstleistungskaufmann~Finanzdienstleistungskauffrau/ Finanzdienstleistungskaufmann/-frau
# /berufe/2515-FinanzierungsberaterIn/ FinanzierungsberaterIn
# /berufe/2817-FingernageldesignerIn/ FingernageldesignerIn
# /berufe/2302-Finno-UgristIn/ Finno-UgristIn
# /berufe/1654-FirmenkundenberaterIn/ FirmenkundenberaterIn
# /berufe/3654-First-Second-Level-Supporter-%28m-w%29/ First/ Second Level Supporter (m/w)
# /berufe/60-FitnessbetreuerIn/ FitnessbetreuerIn
# /berufe/3224-FitnesstrainerIn/ FitnesstrainerIn
# /berufe/3612-FitnesstrainerIn/ FitnesstrainerIn
# /berufe/3337-FlaechenwidmungsplanerIn/ FlächenwidmungsplanerIn
# /berufe/61-FleischverarbeiterIn/ FleischverarbeiterIn
# /berufe/3811-Fleischverarbeitungshilfskraft_%28m_w%29/ Fleischverarbeitungshilfskraft (m/w)
# /berufe/236-FleischverkaeuferIn/ FleischverkäuferIn
# /berufe/3479-FloristIn/ FloristIn
# /berufe/3034-FlugbegleiterIn/ FlugbegleiterIn
# /berufe/3558-FlugdienstberaterIn/ FlugdienstberaterIn
# /berufe/2901-FlughafenarbeiterIn/ FlughafenarbeiterIn
# /berufe/2902-FluglehrerIn/ FluglehrerIn
# /berufe/2903-Fluglotse_Fluglotsin/ Fluglotse/Fluglotsin
# /berufe/1976-FlugzeugbautechnikerIn/ FlugzeugbautechnikerIn
# /berufe/3772-Food_StylistIn/ Food StylistIn
# /berufe/1867-Food-and-Beverage-ManagerIn/ Food-and-Beverage-ManagerIn
# /berufe/3004-FoerdertechnikerIn-FoerderanlagentechnikerIn/ Förder- und FörderanlagentechnikerIn
# /berufe/3093-ForensischeR-Psychologe~Psychologin/ Forensischer Psychologe/Forensische Psychologin
# /berufe/2101-F_und_E-TechnikerIn/ Forschungs- und EntwicklungstechnikerIn
# /berufe/2582-ForschungstechnikerIn-EntwicklungstechnikerIn/ Forschungs- und EntwicklungstechnikerIn
# /berufe/3826-Forschungs-und_EntwicklungstechnikerIn_fuer_E_Mobilitaet/ Forschungs- und EntwicklungstechnikerIn für E-Mobilität
# /berufe/3094-ForschungsmanagerIn/ ForschungsmanagerIn
# /berufe/3705-ForstarbeiterIn/ ForstarbeiterIn
# /berufe/3820-FoersterIn/ FörsterIn
# /berufe/3480-ForsttechnikerIn/ ForsttechnikerIn
# /berufe/1854-ForstwartIn/ ForstwartIn
# /berufe/2612-ForstwirtIn/ ForstwirtIn
# /berufe/3040-Fotokaufmann~Fotokauffrau_Multimediakaufmann~Multimediakauffrau/ Foto- und Multimediakaufmann/-frau
# /berufe/1993-FotografIn/ FotografIn
# /berufe/2324-FotografIn-kuenstlerische-Fotografie/ FotografIn - künstlerische Fotografie
# /berufe/2845-Fotomodell/ Fotomodell
# /berufe/3095-FotoredakteurIn/ FotoredakteurIn
# /berufe/2090-FreizeitberaterIn/ FreizeitberaterIn
# /berufe/2210-FreizeitberaterIn/ FreizeitberaterIn
# /berufe/2089-FreizeitbetreuerIn/ FreizeitbetreuerIn
# /berufe/2211-FreizeitmanagerIn/ FreizeitmanagerIn
# /berufe/5819-FreizeitpaedagogIn/ Freizeitpädagoge/-pädagogin
# /berufe/2264-Freizeitpaedagoge~Freizeitpaedagogin/ Freizeitpädagoge/Freizeitpädagogin
# /berufe/2212-FreizeitwissenschafterIn/ FreizeitwissenschafterIn
# /berufe/2779-FremdenfuehrerIn/ FremdenführerIn
# /berufe/2313-LektorIn-Fremdsprachen/ Fremdsprachen-LektorIn
# /berufe/2064-FremdsprachenkorrespondentIn/ FremdsprachenkorrespondentIn
# /berufe/68-FriedhofsgaertnerIn-ZiergaertnerIn/ Friedhofs- und ZiergärtnerIn
# /berufe/2874-FriedhofsaufseherIn/ FriedhofsaufseherIn
# /berufe/69-FriseurIn-PerueckenmacherIn-StylistIn/ FriseurIn (StylistIn)
# /berufe/3096-Fruehfoerderer~Fruehfoerderin/ Frühförderer/Frühförderin
# /berufe/1953-Flotten-ManagerIn-FuhrparkmanagerIn/ FuhrparkmanagerIn
# /berufe/2493-FundraiserIn/ FundraiserIn
# /berufe/3553-Fundraising-ManagerIn/ FundraiserIn
# /berufe/2687-FunktechnikerIn/ FunktechnikerIn
# /berufe/2818-FussballtrainerIn/ FußballtrainerIn
# /berufe/3566-FupflegerIn/ FußpflegerIn
# /berufe/70-FusspflegerIn/ FußpflegerIn (auslaufend ab 1.2.2024)
# /berufe/5821-FusspflegerIn_%28Podologe_Podologin%29/ FußpflegerIn (Podologe/Podologin) (gültig ab 1.2.2024)
# /berufe/3097-Game-DesignerIn/ Game DesignerIn
# /berufe/3569-Game-Designer/ Game-DesignerIn
# /berufe/3604-Game-DesignerIn/ Game-DesignerIn
# /berufe/3226-GaragenwartIn/ GaragenwartIn
# /berufe/2846-Garderobier~Garderobiere/ Garderobier/Garderobiere
# /berufe/126-GartengestalterIn-GruenflaechengestalterIn/ Garten- und GrünflächengestalterIn
# /berufe/1858-GartenbautechnikerIn/ GartenbautechnikerIn
# /berufe/5820-GartenbautechnikerIn_fuer_Gebaeudebegruenung/ GartenbautechnikerIn für Gebäudebegrünung
# /berufe/3842-GaertnerIn/ GärtnerIn
# /berufe/1868-GastgewerbeassistentIn/ GastgewerbeassistentIn
# /berufe/1634-Gastronomiefachmann~Gastronomiefachfrau/ Gastronomiefachmann/-frau
# /berufe/2288-GebaerdensprachdolmetscherIn/ GebärdensprachdolmetscherIn
# /berufe/2932-GebaerdensprachdolmetscherIn/ GebärdensprachdolmetscherIn
# /berufe/1840-GebaeudetechnikerIn/ GebäudetechnikerIn
# /berufe/2993-GebaeudetechnikerIn/ GebäudetechnikerIn
# /berufe/3862-GebaeudetechnikerIn_fuer_Smart_Building/ GebäudetechnikerIn für Smart Building
# /berufe/3663-GebaeudetechnikplanerIn/ GebäudetechnikplanerIn
# /berufe/3770-Gedaechtnistrainer_Gedaechtnistrainerin/ GedächtnistrainerIn
# /berufe/1937-Gemuesebauer~Gemuesebaeuerin/ Gemüsebauer/-bäuerin
# /berufe/1860-GemuesegaertnerIn/ GemüsegärtnerIn
# /berufe/3098-GenderwissenschafterIn/ GenderwissenschafterIn
# /berufe/2230-Genealoge~Genealogin/ Genealoge/Genealogin
# /berufe/2615-GenetikerIn/ GenetikerIn
# /berufe/2617-GentechnikerIn/ GentechnikerIn
# /berufe/2723-GeochemikerIn/ GeochemikerIn
# /berufe/2710-GeografIn/ GeografIn
# /berufe/2712-GeografIn-Physische-Geografie/ GeografIn für Physische Geografie
# /berufe/3354-GeoinformatikerIn/ GeoinformatikerIn
# /berufe/3359-GeoinformationstechnikerIn/ GeoinformationstechnikerIn
# /berufe/2706-Geologe~Geologin/ Geologe/Geologin
# /berufe/2719-GeophysikerIn/ GeophysikerIn
# /berufe/2704-GeotechnikerIn/ GeotechnikerIn
# /berufe/237-GerberIn/ GerberIn
# /berufe/3080-DolmetscherIn-Gerichtsdolmetschen/ GerichtsdolmetscherIn
# /berufe/2770-GerichtsvollzieherIn/ GerichtsvollzieherIn
# /berufe/2316-GermanistIn/ GermanistIn
# /berufe/2252-Gerontologe~Gerontologin/ Gerontologe/Gerontologin
# /berufe/2761-GeruesterIn/ GerüsterIn
# /berufe/2265-Paedagoge~Paedagogin-Geschlechterforschung-Sozialforschung/ Geschlechter- und SozialforscherIn
# /berufe/2291-UebersetzerIn-und-DolmetscherIn-Gespraechsdolmetschen-Uebersetzen/ GesprächsdolmetscherIn
# /berufe/2727-GesteinshuettentechnikerIn/ GesteinshüttentechnikerIn
# /berufe/3754-GesundheitsmanagerIn/ GesundheitsmanagerIn
# /berufe/2477-GesundheitsmanagerIn/ GesundheitsmanagerIn
# /berufe/3215-Gesundheitspsychologe~Gesundheitspsychologin/ Gesundheitspsychologe/-psychologin
# /berufe/2989-LebensmitteltechnikerIn-Getraenketechnologie/ GetränketechnikerIn
# /berufe/3598-GetraenketechnikerIn/ GetränketechnikerIn
# /berufe/1938-Getreidebauer-baeuerin/ Getreidebauer/-bäuerin
# /berufe/2788-GewerblicheR-MasseurIn/ GewerblicheR MasseurIn
# /berufe/3101-GhostwriterIn/ GhostwriterIn
# /berufe/3267-GiessereitechnikerIn/ GießereitechnikerIn
# /berufe/3749-GipsassistentIn/ GipsassistentIn
# /berufe/3321-GipsassistentIn/ GipsassistentIn
# /berufe/3420-GlasbautechnikerIn-Hauptmodul_Glasbau/ GlasbautechnikerIn - Hauptmodul Glasbau
# /berufe/3421-GlasbautechnikerIn-Hauptmodul_Glaskonstruktionen/ GlasbautechnikerIn - Hauptmodul Glaskonstruktionen
# /berufe/75-GlasblaeserIn-GlasinstrumentenerzeugerIn/ GlasbläserIn und GlasinstrumentenerzeugerIn
# /berufe/1887-GlasgestalterIn/ GlasgestalterIn
# /berufe/242-GlasmacherIn/ GlasmacherIn
# /berufe/3841-GlastechnikerIn/ GlastechnikerIn
# /berufe/3491-GlasverfahrenstechnikerIn_Schwerpunkt_Flachglasveredelung/ GlasverfahrenstechnikerIn - Schwerpunkt Flachglasveredelung
# /berufe/3490-GlasverfahrenstechnikerIn-Schwerpunkt_Hohlglasproduktion/ GlasverfahrenstechnikerIn - Schwerpunkt Hohlglasproduktion
# /berufe/3316-GleisbautechnikerIn/ GleisbautechnikerIn
# /berufe/79-GoldschmiedIn-SilberschmiedIn-JuwelierIn/ Gold- und SilberschmiedIn und JuwelierIn
# /berufe/78-GoldstickerIn-SilberstickerIn-PerlenstickerIn/ Gold-, Silber- und PerlenstickerIn
# /berufe/2819-GolflehrerIn/ GolflehrerIn
# /berufe/3102-GrafikdesignerIn/ GrafikdesignerIn
# /berufe/1995-Grafik-DesignerIn/ GrafikdesignerIn
# /berufe/2331-GrafikerIn/ GrafikerIn
# /berufe/2875-GreenkeeperIn/ GreenkeeperIn
# /berufe/80-Grosshandelskaufmann~Grosshandelskauffrau/ Großhandelskaufmann/-frau
# /berufe/2904-Ground-Host~Gound-Hostess/ Ground Host/ Ground Hostess
# /berufe/1856-GutsverwalterIn/ GutsverwalterIn
# /berufe/2789-GymnastiktrainerIn/ GymnastiktrainerIn
# /berufe/2905-HafenmeisterIn/ HafenmeisterIn
# /berufe/82-HafnerIn/ HafnerIn
# /berufe/1806-HalbleitertechnikerIn/ HalbleitertechnikerIn
# /berufe/2159-HandelsvertreterIn/ HandelsagentIn
# /berufe/2813-Handelsgehilfe-Handelsgehilfin/ Handelsgehilfe/-gehilfin
# /berufe/1954-Handelskaufmann~Handelskauffrau/ Handelskaufmann/-frau
# /berufe/2805-HandelsvertreterIn/ HandelsvertreterIn
# /berufe/83-HandschuhmacherIn/ HandschuhmacherIn
# /berufe/1825-Hardware-EntwicklerIn/ Hardware-EntwicklerIn
# /berufe/2732-HardwareentwicklerIn/ HardwareentwicklerIn
# /berufe/84-HarmonikamacherIn/ HarmonikamacherIn
# /berufe/2877-HausbetreuerIn/ HausbetreuerIn
# ...
# /berufe/3512-Sportgeraetefachkraft/ Sportgerätefachkraft (m/w)
# /berufe/3006-SportgeraetetechnikerIn/ SportgerätetechnikerIn
# /berufe/2959-SportjournalistIn/ SportjournalistIn
# /berufe/2218-SportmanagerIn/ SportmanagerIn
# /berufe/3613-SportmanagerIn/ SportmanagerIn
# /berufe/3248-SportplatzwartIn/ SportplatzwartIn
# /berufe/3180-SporttrainerIn/ SporttrainerIn
# /berufe/3312-SporttrainerIn-SportinstruktorIn/ SporttrainerIn und -instruktorIn
# /berufe/2213-SportwissenschafterIn/ SportwissenschafterIn
# /berufe/2214-SportwissenschafterIn-Bewegung/ SportwissenschafterIn - Bewegung
# /berufe/2216-SportwissenschafterIn-Leistungssport/ SportwissenschafterIn - Leistungssport
# /berufe/2217-SportwissenschafterIn-Trainingswissenschaft/ SportwissenschafterIn - Trainingswissenschaft
# /berufe/2296-SprachwissenschafterIn-KulturwissenschafterIn/ Sprach- und KulturwissenschafterIn
# /berufe/2948-SprachlehrerIn/ SprachlehrerIn
# /berufe/2315-SprachwissenschafterIn-LinguistIn/ SprachwissenschafterIn, LinguistIn
# /berufe/2766-SprengbefugteR/ SprengbefugteR
# /berufe/3669-SPS-ProgrammiererIn/ SPS-ProgrammiererIn
# /berufe/2516-Staatsanwalt~Staatsanwaeltin/ Staatsanwalt/Staatsanwältin
# /berufe/3847-Stadt-undRegionalmanagerIn/ Stadt- und RegionalmanagerIn
# /berufe/3848-StadtplanerIn/ StadtplanerIn
# /berufe/3813-StallarbeiterIn/ StallarbeiterIn
# /berufe/2772-Standesbeamter_beamtin/ Standesbeamter/-beamtin
# /berufe/2811-StaplerfahrerIn/ StaplerfahrerIn
# /berufe/2616-StatistikerIn/ StatistikerIn
# /berufe/2620-StatistikerIn-Naturwissenschaftlich-Technische-Statistik/ StatistikerIn - Naturwissenschaftlich-Technische Statistik
# /berufe/2858-StatistIn/ StatistIn
# /berufe/190-SteinmetzIn/ SteinmetzIn
# /berufe/3497-SteinmetztechnikerIn/ SteinmetztechnikerIn
# /berufe/2911-StellwerksmitarbeiterIn/ StellwerksmitarbeiterIn
# /berufe/1760-SteuerassistentIn/ SteuerassistentIn
# /berufe/3275-SteuerassistentIn/ SteuerassistentIn
# /berufe/2456-SteuerberaterIn/ SteuerberaterIn
# /berufe/2670-SteuerungstechnikerIn-RegelungstechnikerIn/ Steuerungs- und RegelungstechnikerIn
# /berufe/3181-Storyliner/ Storyliner (m/w)
# /berufe/3865-StrahlenschutzbeauftragteR/ StrahlenschutzbeauftragteR
# /berufe/2937-ParkraumueberwacherIn/ Straßenaufsichtsorgan (m/w)
# /berufe/3692-StrassenbahnfahrerIn/ StraßenbahnfahrerIn
# /berufe/2767-StrassenbauarbeiterIn/ StraßenbauarbeiterIn
# /berufe/194-Strassenerhaltungsfachmann~Strassenerhaltungsfachfrau/ Straßenerhaltungsfachmann/-frau
# /berufe/2884-StrassenreinigerIn/ StraßenreinigerIn
# /berufe/195-StreichinstrumentenbauerIn-SaiteninstrumentenbauerIn/ Streich- und SaiteninstrumentenbauerIn
# /berufe/2784-Stubenmaedchen~Stubenbursch/ Stubenmädchen/-bursch
# /berufe/197-StuckateurIn-TrockenausbauerIn/ StuckateurIn und TrockenausbauerIn
# /berufe/3592-StuckateurIn-TrockenausbauerIn/ StuckateurIn und TrockenausbauerIn
# /berufe/3182-StudiotechnikerIn/ StudiotechnikerIn
# /berufe/3661-StudiotechnikerIn/ StudiotechnikerIn
# /berufe/2826-Stuntman~Stuntwoman/ Stuntman/-woman
# /berufe/3184-SuchtberaterIn/ SuchtberaterIn
# /berufe/3185-Suchtpsychologe~Suchtpsychologin/ Suchtpsychologe/Suchtpsychologin
# /berufe/3186-SuedasienwissenschafterIn/ SüdasienwissenschafterIn
# /berufe/2272-SupervisorIn/ SupervisorIn
# /berufe/2513-Supply-Chain-ManagerIn/ Supply-Chain ManagerIn
# /berufe/3547-Supply-Chain-ManagerIn/ Supply-Chain-ManagerIn
# /berufe/3187-Support-ManagerIn/ Support-ManagerIn
# /berufe/2827-SurflehrerIn/ SurflehrerIn
# /berufe/3704-SynchronsprecherIn/ SynchronsprecherIn
# /berufe/1916-SystemtechnikerIn-InformationstechnikerIn-IT/ System- und InformationstechnikerIn
# /berufe/2684-SystemanalytikerIn/ SystemanalytikerIn
# /berufe/3188-SystembetreuerIn/ SystembetreuerIn
# /berufe/2735-SystementwicklerIn/ SystementwicklerIn
# /berufe/198-Systemgastronomiefachmann~Systemgastronomiefachfrau/ Systemgastronomiefachmann/-frau
# /berufe/2737-SystemprogrammiererIn/ SystemprogrammiererIn
# /berufe/1828-SystementwicklerIn/ Systemsoftware-EntwicklerIn
# /berufe/3189-SystemtechnikerIn/ SystemtechnikerIn
# /berufe/2444-SystemtheoretikerIn/ SystemtheoretikerIn
# /berufe/2872-Tagesmutter~Tagesvater/ Tagesmutter/Tagesvater
# /berufe/2812-TankwartIn/ TankwartIn
# /berufe/2374-TaenzerIn/ TänzerIn
# /berufe/2950-TaenzerIn/ TänzerIn
# /berufe/2828-TanzlehrerIn/ TanzlehrerIn
# /berufe/2967-Tanzpaedagoge~Tanzpaedagogin/ Tanzpädagoge/Tanzpädagogin
# /berufe/199-TapeziererIn-DekorateurIn/ TapeziererIn und DekorateurIn
# /berufe/3781-TatortreinigerIn/ TatortreinigerIn
# /berufe/2829-TaetowiererIn-und-PiercerIn/ TätowiererIn und PiercerIn
# /berufe/2830-TauchlehrerIn/ TauchlehrerIn
# /berufe/3352-Tax-ManagerIn/ Tax ManagerIn
# /berufe/2912-TaxifahrerIn/ TaxifahrerIn
# /berufe/1698-TeamassistentIn/ TeamassistentIn
# /berufe/2592-Technik-Consultant/ Technik Consultant (m/w)
# /berufe/200-TechnischeR-ZeichnerIn/ Technisch(er/e) ZeichnerIn
# /berufe/2163-TechnischeR_EinkaeuferIn/ TechnischeR EinkäuferIn
# /berufe/2876-TechnischeR-HauswartIn/ TechnischeR HauswartIn
# /berufe/2587-TechnischeR-KontrollorIn/ TechnischeR KontrollorIn
# /berufe/3713-TechnischeR-RedakteurIn/ TechnischeR RedakteurIn
# /berufe/3191-TechnischeR-RedakteurIn/ TechnischeR RedakteurIn
# /berufe/3816-TechnischeR_SachbearbeiterIn/ TechnischeR SachbearbeiterIn
# /berufe/3192-TelekommunikationsmanagerIn/ TelekommunikationsmanagerIn
# /berufe/2691-TelekommunikationstechnikerIn/ TelekommunikationstechnikerIn
# /berufe/2693-TelekommunikationstechnikerIn-Configuration-Management/ TelekommunikationstechnikerIn - Configuration-Management
# /berufe/2694-TelekommunikationstechnikerIn-Fault-Management/ TelekommunikationstechnikerIn - Fault-Management
# /berufe/2692-TelekommunikationstechnikerIn-Netzplanung/ TelekommunikationstechnikerIn - Netzplanung
# /berufe/2690-TelematikerIn/ TelematikerIn
# /berufe/2831-TennislehrerIn/ TennislehrerIn
# /berufe/3561-Terminal-Guide/ Terminal Guide (m/w)
# /berufe/206-TextilchemikerIn/ TextilchemikerIn
# /berufe/2131-TextilchemikerIn/ TextilchemikerIn
# /berufe/2029-TextildesignerIn/ TextildesignerIn
# /berufe/2342-TextildesignerIn/ TextildesignerIn
# /berufe/3377-TextilgestalterIn-Schwerpunkt_Posamentiererei/ TextilgestalterIn - Schwerpunkt Posamentiererei
# /berufe/3378-TextilgestalterIn-Schwerpunkt_Stickerei/ TextilgestalterIn - Schwerpunkt Stickerei
# /berufe/3379-TextilgestalterIn-Schwerpunkt_Strickwaren/ TextilgestalterIn - Schwerpunkt Strickwaren
# /berufe/3380-TextilgestalterIn-Schwerpunkt_Weberei/ TextilgestalterIn - Schwerpunkt Weberei
# /berufe/2132-Textilkaufmann~Textilkauffrau/ Textilkaufmann/-frau
# /berufe/203-TextilreinigerIn/ TextilreinigerIn
# /berufe/2133-TextiltechnikerIn/ TextiltechnikerIn
# /berufe/3331-Textiltechnologe~Textiltechnologin/ Textiltechnolog(e)in
# /berufe/2238-TheaterwissenschafterIn/ TheaterwissenschafterIn
# /berufe/2317-Theologe~Theologin/ Theologe/Theologin
# /berufe/3008-TheoretischeR-PhysikerIn/ Theoretischer Physiker/Theoretische Physikerin
# /berufe/3655-Third-Level-Supporter-%28m-w%29/ Third Level Supporter (m/w)
# /berufe/2310-Tibetologe~Tibetologin-Tibetologie-und-Buddhismuskunde/ Tibetologe/Tibetologin
# /berufe/3610-Ticketing_Agent/ Ticketing Agent (m/w)
# /berufe/207-TiefbauerIn/ TiefbauerIn
# /berufe/3519-TiefbauspezialistIn-Schwerpunkt_Baumaschinenbetrieb/ TiefbauspezialistIn - Schwerpunkt Baumaschinenbetrieb
# /berufe/3520-TiefbauspezialistIn-Schwerpunkt_Siedlungswasserbau/ TiefbauspezialistIn - Schwerpunkt Siedlungswasserbau
# /berufe/3764-TiefbauspezialistIn-Schwerpunkt_Tunnelbautechnik/ TiefbauspezialistIn - Schwerpunkt Tunnelbautechnik
# /berufe/3521-TiefbauspezialistIn-Schwerpunkt_Verkehrswegebau/ TiefbauspezialistIn - Schwerpunkt Verkehrswegebau
# /berufe/1678-TiefbautechnikerIn/ TiefbautechnikerIn
# /berufe/2544-TiefbautechnikerIn/ TiefbautechnikerIn
# /berufe/2482-Tierarzt~Tieraerztin/ Tierarzt/-ärztin
# /berufe/2484-Tierarzt~Tieraerztin_fuer_Tiermedizinische-Forschung/ Tierarzt/-ärztin für Tiermedizinische Forschung
# /berufe/2485-Tierarzt~Tieraerztin_fuer_Veterinaerverwaltung/ Tierarzt/-ärztin für Veterinärverwaltung
# /berufe/3498-TieraerztlicheR_OrdinationsassistentIn/ Tierärztlich(er/e) OrdinationsassistentIn
# /berufe/3251-TierhaendlerIn/ TierhändlerIn
# /berufe/209-TierpflegerIn/ TierpflegerIn
# /berufe/3554-TiertrainerIn/ TiertrainerIn
# /berufe/3803-TischlereitechnikerIn_-_Schwerpunkt_Modell-_und_Formenbau/ TischlereitechnikerIn - Schwerpunkt Modell- und Formenbau
# /berufe/3472-TischlereitechnikerIn_-_Schwerpunkt_Planung/ TischlereitechnikerIn - Schwerpunkt Planung
# /berufe/3473-TischlereitechnikerIn-Schwerpunkt_Produktion/ TischlereitechnikerIn - Schwerpunkt Produktion
# /berufe/3800-TischlerIn_-_Schwerpunkt_Allgemeine_Tischlerei/ TischlerIn - Schwerpunkt Allgemeine Tischlerei
# /berufe/3801-TischlerIn_-_Schwerpunkt_Drechslerei/ TischlerIn - Schwerpunkt Drechslerei
# /berufe/3194-Tissue-Engineer/ Tissue Engineer (m/w)
# /berufe/3195-ToncutterIn/ ToncutterIn
# /berufe/2679-TontechnikerIn_TonmeisterIn/ ToningenieurIn
# /berufe/3196-TonmeisterIn/ TonmeisterIn
# /berufe/3709-TontechnikerIn/ TontechnikerIn
# /berufe/1838-TontechnikerIn/ TontechnikerIn
# /berufe/2958-TourismusberaterIn/ TourismusberaterIn
# /berufe/2145-Tourismuskaufmann-frau/ Tourismuskaufmann/-frau
# /berufe/2146-TourismusmanagerIn/ TourismusmanagerIn
# /berufe/2219-TourismusmanagerIn/ TourismusmanagerIn
# /berufe/2476-Toxikologe~Toxikologin/ Toxikologe/Toxikologin
# /berufe/3252-TrafikantIn/ TrafikantIn
# /berufe/3197-Trailer-ProducerIn/ Trailer-ProducerIn
# /berufe/2873-TrainerIn-in-der-Erwachsenenbildung/ TrainerIn in der Erwachsenenbildung
# /berufe/3746-TrainingstherapeutIn/ TrainingstherapeutIn
# /berufe/2913-TransportarbeiterIn/ TransportarbeiterIn
# /berufe/3038-TransportbetontechnikerIn/ TransportbetontechnikerIn
# /berufe/2514-TransportmanagerIn/ TransportmanagerIn
# /berufe/1957-TransportsachbearbeiterIn/ TransportsachbearbeiterIn
# /berufe/3198-Treasury-ManagerIn/ Treasury ManagerIn
# /berufe/3199-Trendscout/ Trendscout (m/w)
# /berufe/2914-TriebfahrzeugfuehrerIn/ TriebfahrzeugführerIn
# /berufe/2311-Turkologe~Turkologin/ Turkologe/Turkologin
# /berufe/3253-TuersteherIn/ TürsteherIn
# /berufe/3691-U-Bahn-FahrerIn/ U-Bahn-FahrerIn
# /berufe/2289-UebersetzerIn/ ÜbersetzerIn
# /berufe/2290-UebersetzerIn-und-DolmetscherIn-bei-der-EU_Sonderlaufbahn-Sprachendienst-LA/ ÜbersetzerIn/DolmetscherIn im EU-Sprachdienst
# /berufe/3330-UhrmacherIn-ZeitmesstechnikerIn/ UhrmacherIn - ZeitmesstechnikerIn
# /berufe/2457-WirtschaftsprueferIn-SteuerberaterIn/ WirtschaftsprüferIn
# /berufe/2625-WirtschaftsstatistikerIn/ WirtschaftsstatistikerIn
# /berufe/2751-WirtschaftswissenschafterIn/ WirtschaftswissenschafterIn
# /berufe/2440-WissenschaftlicheR-MitarbeiterIn_KuenstlerischeR-MitarbeiterIn/ WissenschaftlicheR bzw. künstlerischeR MitarbeiterIn
# /berufe/2251-WissenschaftsforscherIn/ WissenschaftsforscherIn
# /berufe/2246-WissenschaftsjournalistIn/ WissenschaftsjournalistIn
# /berufe/3351-WissensmanagerIn/ WissensmanagerIn
# /berufe/3313-Yoga-LehrerIn/ Yoga-LehrerIn
# /berufe/3791-Youtuber/ YouTuber (m/w)
# /berufe/2428-Zahnarzt~Zahnaerztin/ Zahnarzt/-ärztin
# /berufe/2802-ZahnaerztlicheR-AssistentIn/ ZahnarztassistentIn
# /berufe/3037-ZahnaerztlicheR-FachassistentIn/ Zahnärztlich(er/e) FachassistentIn
# /berufe/230-ZahntechnikerIn/ ZahntechnikerIn
# /berufe/3499-ZahntechischeR_FachassistentIn/ Zahntechnisch(er/e) FachassistentIn
# /berufe/3264-ZeitungszustellerIn/ ZeitungszustellerIn
# /berufe/3295-Zellbiologe~Zellbiologin/ Zellbiologe/Zellbiologin
# /berufe/3671-ZerspanungstechnikerIn/ ZerspanungstechnikerIn
# /berufe/1862-ZierpflanzengaertnerIn/ ZierpflanzengärtnerIn
# /berufe/3381-ZimmereitechnikerIn/ ZimmereitechnikerIn
# /berufe/232-Zimmerer~Zimmerin/ Zimmerer/Zimmerin
# /berufe/2578-ZiviltechnikerIn-Architektur/ ZiviltechnikerIn - Architektur
# /berufe/2576-ZiviltechnikerIn-IngenieurkonsulentIn/ ZiviltechnikerIn - IngenieurkonsulentIn
# /berufe/1959-ZolldeklarantIn/ ZolldeklarantIn
# /berufe/3549-Zollwachebeamter~Zollwachebeamtin/ Zollwachebeamter/-beamtin
# /berufe/2599-ZoologIn/ Zoologe/Zoologin
# /berufe/2917-ZugbegleiterIn/ ZugbegleiterIn
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[51], line 78
#      75 time.sleep(ran)
#      77 # Click the page button and wait for the page to load
# ---> 78 page_btn.click()
#      79 WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.TAG_NAME, "table")))
#      81 # Parse the page
#
# File c:\anaconda3\envs\DSI\lib\site-packages\selenium\webdriver\remote\webelement.py:80, in WebElement.click(self)
#      78 def click(self):
#      79     """Clicks the element."""
# ---> 80     self._execute(Command.CLICK_ELEMENT)
#
# File c:\anaconda3\envs\DSI\lib\site-packages\selenium\webdriver\remote\webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File c:\anaconda3\envs\DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\anaconda3\envs\DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: Element <a href="#"> could not be scrolled into view

# %% [markdown]
# Save to File

# %%
import os
import csv

# Check if file exists
if not os.path.exists('data/professions.csv'):
    # If file does not exist, write to file
    with open('professions.csv', 'w', newline='') as f:
        writer = csv.writer(f, delimiter=';')
        for key in professions.keys():
            writer.writerow([key, professions[key]])
else:
    # If file exists, retrieve from file
    with open('data/professions.csv', 'r') as f:
        reader = csv.reader(f, delimiter=';')
        professions = {rows[0]:rows[1] for rows in reader}

# %% [markdown]
# # Scrape Individual Profession
#
# working

# %%
import requests
from bs4 import BeautifulSoup
import json
import random
import time
import os


# Check if file exists
if os.path.exists('data/berufslexikon.json'):
    # If file exists, read existing data
    with open('data/berufslexikon.json', 'r', encoding='utf-8') as f:
        existing_data = json.load(f)
        last_profession = existing_data[-1]['profession'] if existing_data else None
else:
    last_profession = None

start = False if last_profession else True

for key, value in professions.items():
    if not start and key == last_profession:
        start = True
        continue

    if not start:
        continue

    url = "https://www.berufslexikon.at" + value
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the page content
    page_content = soup.find(id='pageContent')

    # Prepare data for JSON
    data = {
        "profession": key,
        "url": url,
        "content": page_content.text if page_content else None
    }

    # If file does not exist or is empty, write data as the first item of a list
    if not os.path.isfile('data/berufslexikon.json') or os.stat('data/berufslexikon.json').st_size == 0:
        with open('data/berufslexikon.json', 'w', encoding='utf-8') as f:
            json.dump([data], f, ensure_ascii=False, indent=4)
    else:
        # If file exists and is not empty, append data to the list
        with open('data/berufslexikon.json', 'r+', encoding='utf-8') as f:
            existing_data = json.load(f)
            existing_data.append(data)
            f.seek(0)  # reset file position to the beginning
            json.dump(existing_data, f, ensure_ascii=False, indent=4)

    # wait for random time
    #ran = random.randint(1, 5)/1000
    #time.sleep(ran)
    print(key, value)
print("done")
# Out:
# MusikerIn /berufe/2938-MusikerIn/
# MusikerIn - Elektroakustische Musik /berufe/2376-MusikerIn-Elektroakustische-Musik/
# MusikinstrumentenerzeugerIn /berufe/1892-MusikinstrumentenerzeugerIn/
# Musikpädagoge/Musikpädagogin /berufe/2368-Musikpaedagoge~Musikpaedagogin/
# MusiktherapeutIn /berufe/2371-MusiktherapeutIn/
# MusikwissenschafterIn /berufe/2236-MusikwissenschafterIn/
# NachhaltigkeitsbeauftragteR /berufe/3822-NachhaltigkeitsbeauftragteR/
# NachhaltigkeitsmanagerIn /berufe/3861-NachhaltigkeitsmanagerIn/
# NachmittagsbetreuerIn /berufe/3235-NachmittagsbetreuerIn/
# NachrichtentechnikerIn /berufe/3286-NachrichtentechnikerIn/
# NachrichtentechnikerIn für Funktechnik /berufe/1909-NachrichtentechnikerInfrFunktechnik/
# Nah- und DistributionslogistikerIn /berufe/3511-Nah-_und_DistributionslogistikerIn/
# NäherIn /berufe/3708-NaeherIn/
# NanotechnikerIn /berufe/2680-NanotechnikerIn/
# NationalparkrangerIn /berufe/3236-NationalparkrangerIn/
# NaturraummanagerIn /berufe/2988-NaturraummanagerIn/
# NederlandistIn /berufe/2965-NederlandistIn/
# NetzwerkadministratorIn /berufe/2696-NetzwerkadministratorIn/
# NetzwerktechnikerIn /berufe/2695-NetzwerktechnikerIn/
# Neuropsychologe/Neuropsychologin /berufe/3152-Neuropsychologe~Neuropsychologin/
# NotarIn /berufe/2533-NotarIn/
# NumismatikerIn /berufe/2233-NumismatikerIn/
# ObduktionsassistentIn /berufe/3324-ObduktionsassistentIn/
# OberflächentechnikerIn /berufe/2045-OberflaechentechnikerIn/
# OberteilherrichterIn /berufe/149-OberteilherrichterIn/
# Obst- und GemüsekonserviererIn /berufe/150-ObstkonserviererIn-GemuesekonserviererIn/
# Obstbauer/-bäuerin /berufe/1945-Obstbauer~Obstbaeuerin/
# Ofenbau- und VerlegetechnikerIn /berufe/3374-OfenbautechnikerIn_und_VerlegetechnikerIn/
# Office Assistant (m/w) /berufe/2065-Office-Assistant/
# Öko-AuditorIn /berufe/2636-Oeko-AuditorIn/
# Öko-DesignerIn /berufe/3860-Oeko-DesignerIn/
# Ökologe/Ökologin /berufe/2629-Oekologe~Oekologin/
# Ökotrophologe/Ökotrophologin /berufe/2610-Oekotrophologe~Oekotrophologin/
# Online-HändlerIn /berufe/3156-Online-HaendlerIn/
# Online-Marketing ManagerIn /berufe/2546-Online-Marketing-ManagerIn/
# Online-Marketing-ManagerIn /berufe/3778-Online_Marketing_ManagerIn/
# Online-RedakteurIn /berufe/2249-Online-RedakteurIn/
# OperationsassistentIn /berufe/3325-OperationsassistentIn/
# OptoelektronikerIn /berufe/2996-OptoelektronikerIn/
# OptotechnikerIn /berufe/1991-OptotechnikerIn/
# OrdinationsassistentIn /berufe/3326-OrdinationsassistentIn/
# Ordinationshilfe bei TierärztInnen /berufe/2837-Ordinationshilfe-bei-TieraerztInnen/
# OrgelbauerIn /berufe/153-OrgelbauerIn/
# OrthopädieschuhmacherIn /berufe/154-OrthopaedieschuhmacherIn/
# OrthopädietechnikerIn /berufe/256-OrthopaedietechnikerIn/
# OrthoptistIn /berufe/2976-OrthoptistIn/
# Outdoor-TrainerIn /berufe/3237-Outdoor-TrainerIn/
# OzeanografIn /berufe/3001-OzeanografIn/
# Pädagoge/Pädagogin /berufe/2253-Paedagoge~Paedagogin/
# Pädagoge/Pädagogin für Integrative Pädagogik /berufe/2267-Paedagoge~Paedagogin-Integrative-Paedagogik/
# Pädagogin/Pädagoge in einer SOS-Kinderdorf-Familie /berufe/3616-Paedagogin_Paedagoge_in_einer_SOS-Kinderdorf-Familie/
# PädagogischeR AssistentIn /berufe/3698-SozialpdagogischeRAssistentIn/
# Pädagogischer Psychologe/Pädagogische Psychologin /berufe/3294-Pdagogischer-Psychologe~Pdagogische-Psychologin/
# Paläobiologe/-biologin /berufe/3523-Palobiologe-Palobiologin/
# PaläografIn /berufe/2234-PalaeografIn/
# Paläontologe/Paläontologin /berufe/2602-Palaeontologe_Palaeontologin/
# PapiertechnikerIn /berufe/155-PapiertechnikerIn/
# Patentanwalt/Patentanwältin /berufe/2985-Patentanwalt~Patentanwaeltin/
# PatentassessorIn /berufe/3159-PatentassessorIn/
# Personal-ControllerIn /berufe/3160-Personal-ControllerIn/
# Personal-TrainerIn /berufe/2091-Personal-TrainerIn/
# Personaldienstleistungskaufmann/-frau /berufe/3579-Personaldienstleistungskaufmann~Personaldienstleistungskauffrau/
# PersonalentwicklerIn /berufe/3014-PersonalentwicklerIn/
# PersonalmanagerIn /berufe/2483-PersonalmanagerIn/
# PersonalreferentIn /berufe/2486-PersonalreferentIn/
# PersonalsachbearbeiterIn /berufe/2048-PersonalsachbearbeiterIn/
# PersonalverrechnerIn /berufe/2939-PersonalverrechnerIn/
# PersonalverwaltungsassistentIn /berufe/3238-PersonalverwaltungsassistentIn/
# PersonenbetreuerIn in der 24-Stunden-Betreuung /berufe/3239-PersonenbetreuerIn-24-Stunden-Betreuung/
# PersönlicheR AssistentIn /berufe/3769-PersoenlicheR_AssistentIn/
# Petrologe/Petrologin /berufe/3000-Petrologe_Petrologin/
# Pflasterer/Pflasterin /berufe/157-Pflasterer~Pflasterin/
# PflegeassistentIn /berufe/3620-PflegeassistentIn/
# PflegeassistentIn (Lehrberuf) /berufe/3832-PflegeassistentIn_Lehrberuf/
# PflegefachassistentIn /berufe/3484-PflegefachassistentIn/
# PflegefachassistentIn (Lehrberuf) /berufe/3833-PflegefachassistentIn_Lehrberuf/
# PflegemanagerIn /berufe/2970-PflegemanagerIn/
# PflegewissenschafterIn /berufe/2971-PflegewissenschafterIn/
# Pharmakologe/Pharmakologin /berufe/2471-Pharmakologe~Pharmakologin/
# Pharmakologe/Pharmakologin - Schwerpunkt Drug Safety /berufe/2474-Pharmakologe~Pharmakologin-Drug-Safety/
# Pharmakologe/Pharmakologin - Schwerpunkt Produktmanagement /berufe/2473-Pharmakologe~Pharmakologin-Produktmanagement-Produktmarketing/
# PharmareferentIn /berufe/2941-PharmareferentIn/
# Pharmatechnolog(e)in /berufe/3032-Pharmatechnologe~Pharmatechnologin/
# PharmazeutIn /berufe/2460-PharmazeutIn/
# PharmazeutIn - Schwerpunkt Pharmakognosie /berufe/2462-PharmazeutIn-Pharmakognosie/
# PharmazeutIn - Schwerpunkt Pharmazeutische Chemie /berufe/2467-PharmazeutIn-Pharmazeutische-Chemie/
# PharmazeutIn - Schwerpunkt Pharmazeutische Technologie /berufe/2469-PharmazeutIn-Pharmazeutische-Technologie/
# Pharmazeutisch-kaufmännisch(er/e) AssistentIn /berufe/158-Pharmazeutisch-kaufmaennischeR-AssistentIn/
# Philologe/Philologin - Schwerpunkt Klassische Philologie /berufe/2314-Philologe~Philologin-Klassische-Philologie-Latein-Altgriechisch/
# PhilosophIn /berufe/2250-PhilosophIn/
# PhysikerIn /berufe/2606-PhysikerIn/
# PhysiotherapeutIn /berufe/2455-PhysiotherapeutIn/
# PilatestrainerIn /berufe/3240-PilatestrainerIn/
# PilotIn /berufe/2909-PilotIn/
# PlakatiererIn /berufe/2855-PlakatiererIn/
# Platten- und FliesenlegerIn /berufe/160-PlattenlegerIn-FliesenlegerIn/
# PlatzmeisterIn /berufe/2764-PlatzmeisterIn/
# PolitikberaterIn /berufe/3301-PolitikberaterIn/
# PolitikwissenschaftlerIn /berufe/2286-PolitikwissenschafterIn/
# Polsterer/Polsterin /berufe/161-Polsterer~Polsterin/
# PolymerchemikerIn /berufe/3163-PolymerchemikerIn/
# PortierIn /berufe/2881-PortierIn/
# PostdienstleisterIn /berufe/2910-PostdienstleisterIn/
# PPS-TechnikerIn /berufe/2059-PPS-TechnikerIn/
# PR-AssistentIn /berufe/2942-PR-AssistentIn/
# PR-BeraterIn /berufe/2243-PR-BeraterIn/
# PräparatorIn /berufe/165-PraeparatorIn/
# PressesprecherIn /berufe/2242-PressesprecherIn/
# Priester /berufe/3525-Priester-katholisch/
# Print-ProducerIn /berufe/2167-Print-ProducerIn/
# PrivatdozentIn /berufe/2438-PrivatdozentIn/
# PrivatkundenberaterIn /berufe/1658-PrivatkundenberaterIn/
# ProduktionsleiterIn (Theater/Film/Fernsehen) /berufe/2365-ProduktionsleiterIn/
# ProduktionsmanagerIn /berufe/2585-ProduktionsmanagerIn/
# ProduktionstechnikerIn /berufe/2060-ProduktionstechnikerIn/
# ProduktmanagerIn /berufe/3576-ProduktmanagerIn/
# ProduktmanagerIn für E-Mobilität /berufe/3829-ProduktmanagerIn_E_Mobilitaet/
# ProgrammiererIn /berufe/3640-ProgrammiererIn/
# ProjektassistentIn /berufe/3581-ProjektassistentIn/
# ProjektassistentIn im Bauwesen /berufe/1676-ProjektassistentIn-Bauwesen/
# ProjektmanagerIn /berufe/2498-ManagerIn-Projektmanagement/
# PromoterIn /berufe/3241-PromoterIn/
# ProzessleittechnikerIn /berufe/1836-ProzessleittechnikerIn/
# ProzessmanagerIn im Gesundheitswesen /berufe/3166-ProzessmanagerIn-Gesundheitswesen/
# ProzesstechnikerIn /berufe/3375-ProzesstechnikerIn/
# PrüffeldtechnikerIn /berufe/3857-PrueffeldtechnikerIn/
# PrüftechnikerIn /berufe/2113-PrueftechnikerIn/
# PrüftechnikerIn - Schwerpunkt Baustoffe /berufe/3767-PrueftechnikerIn_-_Schwerpunkt_Baustoffe/
# PrüftechnikerIn - Schwerpunkt Physik /berufe/3768-PrueftechnikerIn_-_Schwerpunkt_Physik/
# Psychologe/Psychologin /berufe/2268-Psychologe~Psychologin/
# PsychotherapeutIn /berufe/2271-PsychotherapeutIn/
# PublizistIn /berufe/2248-PublizistIn/
# PyrotechnikerIn /berufe/2780-PyrotechnikerIn/
# Qi-Gong-LehrerIn /berufe/2798-Qi-Gong-LehrerIn/
# QualitätsauditorIn /berufe/2604-Qualitaets-AuditorIn/
# QualitätsmanagerIn /berufe/2603-QualitaetsmanagerIn/
# QualitätsmanagerIn in der Biotechnologie /berufe/3167-QualitaetsmanagerIn-Biotechnologie/
# QualitätssicherungstechnikerIn /berufe/2107-QualitaetssicherungstechnikerIn/
# QualitätstechnikerIn /berufe/2605-QualitaetstechnikerIn/
# QualitätstechnikerIn im Fahrzeugbau /berufe/1851-QualitaetstechnikerIn-Fahrzeugbau/
# Radiologietechnologe/-technologin /berufe/2454-Radiologietechnologe~Radiologietechnologin/
# Ramp Agent (m/w) /berufe/3559-Ramp_Agent/
# Rating AnalystIn /berufe/3168-Rating-AnalystIn/
# RauchfangkehrerIn /berufe/168-RauchfangkehrerIn/
# RaumgestalterIn /berufe/1794-RaumgestalterIn/
# RaumpflegerIn /berufe/2882-RaumpflegerIn/
# RaumplanerIn /berufe/2343-RaumplanerIn/
# Rechtsanwalt/-anwältin /berufe/2534-Rechtsanwalt~Rechtsanwaeltin/
# RechtspflegerIn /berufe/2943-RechtspflegerIn/
# RecyclingtechnikerIn /berufe/2641-RecyclingtechnikerIn/
# RedakteurIn /berufe/2169-RedakteurIn/
# REFA-TechnikerIn /berufe/2944-REFA-TechnikerIn/
# ReferentIn /berufe/2510-ReferentIn/
# RegalbetreuerIn /berufe/2810-RegalbetreuerIn/
# RegieassistentIn /berufe/3242-RegieassistentIn/
# RegionalmanagerIn im Tourismus /berufe/3170-RegionalmanagerIn-Tourismus/
# RegisseurIn (Fernsehen, Film, Theater, Oper, Video) /berufe/2366-RegisseurIn-Fernsehen-Film-Theater-Oper-Video/
# Reifen- und VulkanisationstechnikerIn /berufe/3486-ReifentechnikerIn-VulkanisationstechnikerIn/
# ReinigungstechnikerIn /berufe/3376-ReinigungstechnikerIn/
# ReiseberaterIn /berufe/2140-ReiseberaterIn/
# ReisebüroassistentIn /berufe/2143-ReisebueroassistentIn/
# ReiseleiterIn /berufe/2781-ReiseleiterIn/
# ReitlehrerIn /berufe/2822-ReitlehrerIn/
# Religionspädagoge/Religionspädagogin /berufe/2319-Religionspaedagoge~Religionspaedagogin/
# ReprografIn /berufe/171-ReprografIn/
# Requirements Engineer (m/w) /berufe/3693-Requirement-Engineer/
# RequisiteurIn /berufe/3243-RequisiteurIn/
# ResilienztrainerIn /berufe/3773-ResilienztrainerIn/
# Restaurantfachmann/-frau /berufe/172-Restaurantfachmann~Restaurantfachfrau/
# RestaurantmanagerIn /berufe/1875-RestaurantmanagerIn/
# RestauratorIn /berufe/3601-RestauratorIn/
# RettungstaucherIn /berufe/3626-RettungstaucherIn/
# RevisionsassistentIn /berufe/1758-RevisionsassistentIn/
# RevisorIn /berufe/2461-RevisorIn/
# RezeptionistIn /berufe/2782-RezeptionistIn/
# RichterIn /berufe/2512-RichterIn/
# RisikomanagerIn - Corporate Risk Management /berufe/2520-RisikomanagerIn-CorporateRiskManagement/
# RobotiktechnikerIn /berufe/3679-RobotiktechnikerIn/
# Rohstoffgeologe/-geologin /berufe/3099-Rohstoffgeologe~-geologin/
# RohstoffingenieurIn /berufe/3113-RohstoffingenieurIn/
# RomanistIn /berufe/2306-RomanistIn/
# RöntgenassistentIn /berufe/3327-RoentgenassistentIn/
# SachbearbeiterIn /berufe/1697-SachbearbeiterIn/
# Sales Assistant (m/w) /berufe/2162-Sales-Assistent/
# Sales ManagerIn /berufe/2492-Sales-ManagerIn/
# SängerIn /berufe/2857-SaengerIn/
# SanitäterIn /berufe/2799-SanitaeterIn/
# SAP-BeraterIn /berufe/2688-SAP-BeraterIn/
# SattlerIn /berufe/3271-SattlerIn/
# SaunawartIn /berufe/3256-SaunawartIn/
# SchadensreferentIn /berufe/2174-SchadensreferentIn/
# SchädlingsbekämpferIn /berufe/179-SchaedlingsbekaempferIn/
# SchalerIn /berufe/3244-SchalerIn/
# SchauspielerIn /berufe/2856-SchauspielerIn/
# SchiffselektronikerIn - Schwerpunkt Nachrichtentechnik /berufe/2998-SchiffselektronikerIn-Schwerpunkt-Nachrichtentechnik/
# SchiffsmaschinistIn /berufe/3680-SchiffsmaschinistIn/
# SchilehrerIn /berufe/2823-SchilehrerIn/
# SchlosserIn /berufe/3672-SchlosserIn/
# SchmiedetechnikerIn /berufe/3675-SchmiedetechnikerIn/
# SchmuckdesignerIn /berufe/1893-SchmuckdesignerIn/
# SchnittkonstrukteurIn /berufe/2129-SchnittkonstrukteurIn/
# SchuhfertigerIn /berufe/240-SchuhfertigerIn/
# SchuhmacherIn /berufe/185-SchuhmacherIn/
# SchuldnerberaterIn /berufe/3259-SchuldnerberaterIn/
# Schulpsychologe/Schulpsychologin /berufe/3171-Schulpsychologe~Schulpsychologin/
# SchulwartIn /berufe/2883-SchulwartIn/
# SchwarzdeckerIn /berufe/2765-SchwarzdeckerIn/
# SchweißerIn /berufe/3673-SchweierIn/
# SchwimmtrainerIn /berufe/3245-SchwimmtrainerIn/
# Script SupervisorIn /berufe/3172-Script-SupervisorIn/
# Security Agent (m/w) /berufe/3560-Security-Agent/
# SegellehrerIn /berufe/2824-SegellehrerIn/
# SeilbahntechnikerIn /berufe/3328-SeilbahntechnikerIn/
# SeilerIn /berufe/3333-SeilerIn/
# SekretärIn /berufe/2946-SekretaerIn/
# SeniorenanimateurIn /berufe/3247-SeniorenanimateurIn/
# SensortechnikerIn /berufe/2668-SensortechnikerIn/
# SEO-/SEA-ManagerIn /berufe/3706-SEO-SEA-ManagerIn/
# ServicetechnikerIn /berufe/2110-ServicetechnikerIn/
# ServicetechnikerIn für Elektrotechnik /berufe/3664-ServicetechnikerIn_fuer_Elektrotechnik/
# ServicetechnikerIn für Telekommunikation /berufe/3666-ServicetechnikerIn-fuer-Telekommunikation/
# ServicetechnikerIn im Maschinen- und Anlagenbau /berufe/1978-ServicetechnikerIn-Maschinenbau-Anlagenbau/
# Servierkraft (m/w) /berufe/2783-Servierkraft/
# Shiatsu-PraktikerIn /berufe/2800-Shiatsu-PraktikerIn/
# SicherheitsmanagerIn /berufe/2586-SicherheitsmanagerIn/
# SicherheitstechnikerIn /berufe/2947-SicherheitstechnikerIn/
# SignaltechnikerIn /berufe/1815-SignaltechnikerIn/
# Sinologe/Sinologin /berufe/2307-Sinologe~Sinologin/
# SkandinavistIn /berufe/2308-SkandinavistIn/
# SkibautechnikerIn /berufe/3483-SkibautechnikerIn/
# SlawistIn /berufe/2309-SlawistIn/
# SnowboardlehrerIn /berufe/2825-SnowboardlehrerIn/
# Social-Media-ManagerIn /berufe/3701-Social-Media-ManagerIn/
# Software-EntwicklerIn /berufe/2068-Software-EntwicklerIn/
# Software-EntwicklerIn - SCRUM /berufe/3650-Software-EntwicklerIn-SCRUM/
# Software-EntwicklerIn für Anwendungen /berufe/2739-Software-EntwicklerIn-Anwendungen/
# Software-LektorIn /berufe/3174-Software-LektorIn/
# Software-TesterIn /berufe/1829-Software-TesterIn/
# Softwarearchitect /berufe/3356-Softwarearchitect/
# SoftwarebetreuerIn /berufe/3173-SoftwarebetreuerIn/
# SolartechnikerIn /berufe/3529-SolartechnikerIn/
# Sommelier/Sommeliere /berufe/3311-Sommelier~Sommelire/
# SonnenschutztechnikerIn /berufe/187-SonnenschutztechnikerIn/
# Souffleur/Souffleuse /berufe/3246-Souffleur~Souffleuse/
# SounddesignerIn /berufe/3777-SounddesignerIn/
# SozialarbeiterIn /berufe/2273-SozialarbeiterIn/
# SozialarbeitswissenschafterIn /berufe/2962-SozialarbeitswissenschafterIn/
# SozialeR AlltagsbegleiterIn /berufe/3552-SozialeRAlltagsbegleiterIn/
# SozialforscherIn /berufe/2280-SozialforscherIn/
# SozialforscherIn - Empirische Sozialforschung /berufe/2281-SozialforscherIn-Empirische-Sozialforschung/
# SozialforscherIn - Evaluierungsforschung /berufe/2282-SozialforscherIn-Evaluierungsforschung/
# Sozialgerontologe/Sozialgerontologin /berufe/2961-Sozialgerontologe~Sozialgerontologin/
# SozialmanagerIn /berufe/2480-SozialmanagerIn/
# Sozialpädagoge/-pädagogin /berufe/2260-Sozialpaedagoge~Sozialpaedagogin/
# Sozialpsychologe/Sozialpsychologin /berufe/3179-Sozialpsychologe~Sozialpsychologin/
# SozialstatistikerIn /berufe/2622-SozialstatistikerIn/
# SozialwirtIn /berufe/2481-SozialwirtIn/
# Soziologe/Soziologin /berufe/2285-Soziologe~Soziologin/
# Speditionskaufmann/-frau /berufe/188-Speditionskaufmann~Speditionskauffrau/
# SpeditionslogistikerIn /berufe/257-SpeditionslogistikerIn/
# SpenglerIn /berufe/189-SpenglerIn/
# Spielpädagoge/Spielpädagogin /berufe/3524-Spielpaedagoge-Spielpaedagogin/
# SportadministratorIn /berufe/2926-SportadministratorIn/
# SportgerätebautechnikerIn /berufe/1979-SportgeraetebautechnikerIn/
# Sportgerätefachkraft (m/w) /berufe/3512-Sportgeraetefachkraft/
# SportgerätetechnikerIn /berufe/3006-SportgeraetetechnikerIn/
# SportjournalistIn /berufe/2959-SportjournalistIn/
# SportmanagerIn /berufe/3613-SportmanagerIn/
# SportplatzwartIn /berufe/3248-SportplatzwartIn/
# SporttrainerIn /berufe/3180-SporttrainerIn/
# SporttrainerIn und -instruktorIn /berufe/3312-SporttrainerIn-SportinstruktorIn/
# SportwissenschafterIn /berufe/2213-SportwissenschafterIn/
# SportwissenschafterIn - Bewegung /berufe/2214-SportwissenschafterIn-Bewegung/
# SportwissenschafterIn - Leistungssport /berufe/2216-SportwissenschafterIn-Leistungssport/
# SportwissenschafterIn - Trainingswissenschaft /berufe/2217-SportwissenschafterIn-Trainingswissenschaft/
# Sprach- und KulturwissenschafterIn /berufe/2296-SprachwissenschafterIn-KulturwissenschafterIn/
# SprachlehrerIn /berufe/2948-SprachlehrerIn/
# SprachwissenschafterIn, LinguistIn /berufe/2315-SprachwissenschafterIn-LinguistIn/
# SprengbefugteR /berufe/2766-SprengbefugteR/
# SPS-ProgrammiererIn /berufe/3669-SPS-ProgrammiererIn/
# Staatsanwalt/Staatsanwältin /berufe/2516-Staatsanwalt~Staatsanwaeltin/
# Stadt- und RegionalmanagerIn /berufe/3847-Stadt-undRegionalmanagerIn/
# StadtplanerIn /berufe/3848-StadtplanerIn/
# StallarbeiterIn /berufe/3813-StallarbeiterIn/
# Standesbeamter/-beamtin /berufe/2772-Standesbeamter_beamtin/
# StaplerfahrerIn /berufe/2811-StaplerfahrerIn/
# StatistikerIn /berufe/2616-StatistikerIn/
# StatistikerIn - Naturwissenschaftlich-Technische Statistik /berufe/2620-StatistikerIn-Naturwissenschaftlich-Technische-Statistik/
# StatistIn /berufe/2858-StatistIn/
# SteinmetzIn /berufe/190-SteinmetzIn/
# SteinmetztechnikerIn /berufe/3497-SteinmetztechnikerIn/
# StellwerksmitarbeiterIn /berufe/2911-StellwerksmitarbeiterIn/
# SteuerassistentIn /berufe/3275-SteuerassistentIn/
# SteuerberaterIn /berufe/2456-SteuerberaterIn/
# Steuerungs- und RegelungstechnikerIn /berufe/2670-SteuerungstechnikerIn-RegelungstechnikerIn/
# Storyliner (m/w) /berufe/3181-Storyliner/
# StrahlenschutzbeauftragteR /berufe/3865-StrahlenschutzbeauftragteR/
# Straßenaufsichtsorgan (m/w) /berufe/2937-ParkraumueberwacherIn/
# StraßenbahnfahrerIn /berufe/3692-StrassenbahnfahrerIn/
# StraßenbauarbeiterIn /berufe/2767-StrassenbauarbeiterIn/
# Straßenerhaltungsfachmann/-frau /berufe/194-Strassenerhaltungsfachmann~Strassenerhaltungsfachfrau/
# StraßenreinigerIn /berufe/2884-StrassenreinigerIn/
# Streich- und SaiteninstrumentenbauerIn /berufe/195-StreichinstrumentenbauerIn-SaiteninstrumentenbauerIn/
# Stubenmädchen/-bursch /berufe/2784-Stubenmaedchen~Stubenbursch/
# StuckateurIn und TrockenausbauerIn /berufe/3592-StuckateurIn-TrockenausbauerIn/
# StudiotechnikerIn /berufe/3661-StudiotechnikerIn/
# Stuntman/-woman /berufe/2826-Stuntman~Stuntwoman/
# SuchtberaterIn /berufe/3184-SuchtberaterIn/
# Suchtpsychologe/Suchtpsychologin /berufe/3185-Suchtpsychologe~Suchtpsychologin/
# SüdasienwissenschafterIn /berufe/3186-SuedasienwissenschafterIn/
# SupervisorIn /berufe/2272-SupervisorIn/
# Supply-Chain ManagerIn /berufe/2513-Supply-Chain-ManagerIn/
# Supply-Chain-ManagerIn /berufe/3547-Supply-Chain-ManagerIn/
# Support-ManagerIn /berufe/3187-Support-ManagerIn/
# SurflehrerIn /berufe/2827-SurflehrerIn/
# SynchronsprecherIn /berufe/3704-SynchronsprecherIn/
# System- und InformationstechnikerIn /berufe/1916-SystemtechnikerIn-InformationstechnikerIn-IT/
# SystemanalytikerIn /berufe/2684-SystemanalytikerIn/
# SystembetreuerIn /berufe/3188-SystembetreuerIn/
# SystementwicklerIn /berufe/2735-SystementwicklerIn/
# Systemgastronomiefachmann/-frau /berufe/198-Systemgastronomiefachmann~Systemgastronomiefachfrau/
# SystemprogrammiererIn /berufe/2737-SystemprogrammiererIn/
# Systemsoftware-EntwicklerIn /berufe/1828-SystementwicklerIn/
# SystemtechnikerIn /berufe/3189-SystemtechnikerIn/
# SystemtheoretikerIn /berufe/2444-SystemtheoretikerIn/
# Tagesmutter/Tagesvater /berufe/2872-Tagesmutter~Tagesvater/
# TankwartIn /berufe/2812-TankwartIn/
# TänzerIn /berufe/2950-TaenzerIn/
# TanzlehrerIn /berufe/2828-TanzlehrerIn/
# Tanzpädagoge/Tanzpädagogin /berufe/2967-Tanzpaedagoge~Tanzpaedagogin/
# TapeziererIn und DekorateurIn /berufe/199-TapeziererIn-DekorateurIn/
# TatortreinigerIn /berufe/3781-TatortreinigerIn/
# TätowiererIn und PiercerIn /berufe/2829-TaetowiererIn-und-PiercerIn/
# TauchlehrerIn /berufe/2830-TauchlehrerIn/
# Tax ManagerIn /berufe/3352-Tax-ManagerIn/
# TaxifahrerIn /berufe/2912-TaxifahrerIn/
# TeamassistentIn /berufe/1698-TeamassistentIn/
# Technik Consultant (m/w) /berufe/2592-Technik-Consultant/
# Technisch(er/e) ZeichnerIn /berufe/200-TechnischeR-ZeichnerIn/
# TechnischeR EinkäuferIn /berufe/2163-TechnischeR_EinkaeuferIn/
# TechnischeR HauswartIn /berufe/2876-TechnischeR-HauswartIn/
# TechnischeR KontrollorIn /berufe/2587-TechnischeR-KontrollorIn/
# TechnischeR RedakteurIn /berufe/3191-TechnischeR-RedakteurIn/
# TechnischeR SachbearbeiterIn /berufe/3816-TechnischeR_SachbearbeiterIn/
# TelekommunikationsmanagerIn /berufe/3192-TelekommunikationsmanagerIn/
# TelekommunikationstechnikerIn /berufe/2691-TelekommunikationstechnikerIn/
# TelekommunikationstechnikerIn - Configuration-Management /berufe/2693-TelekommunikationstechnikerIn-Configuration-Management/
# TelekommunikationstechnikerIn - Fault-Management /berufe/2694-TelekommunikationstechnikerIn-Fault-Management/
# TelekommunikationstechnikerIn - Netzplanung /berufe/2692-TelekommunikationstechnikerIn-Netzplanung/
# TelematikerIn /berufe/2690-TelematikerIn/
# TennislehrerIn /berufe/2831-TennislehrerIn/
# Terminal Guide (m/w) /berufe/3561-Terminal-Guide/
# TextilchemikerIn /berufe/2131-TextilchemikerIn/
# TextildesignerIn /berufe/2342-TextildesignerIn/
# TextilgestalterIn - Schwerpunkt Posamentiererei /berufe/3377-TextilgestalterIn-Schwerpunkt_Posamentiererei/
# TextilgestalterIn - Schwerpunkt Stickerei /berufe/3378-TextilgestalterIn-Schwerpunkt_Stickerei/
# TextilgestalterIn - Schwerpunkt Strickwaren /berufe/3379-TextilgestalterIn-Schwerpunkt_Strickwaren/
# TextilgestalterIn - Schwerpunkt Weberei /berufe/3380-TextilgestalterIn-Schwerpunkt_Weberei/
# Textilkaufmann/-frau /berufe/2132-Textilkaufmann~Textilkauffrau/
# TextilreinigerIn /berufe/203-TextilreinigerIn/
# TextiltechnikerIn /berufe/2133-TextiltechnikerIn/
# Textiltechnolog(e)in /berufe/3331-Textiltechnologe~Textiltechnologin/
# TheaterwissenschafterIn /berufe/2238-TheaterwissenschafterIn/
# Theologe/Theologin /berufe/2317-Theologe~Theologin/
# Theoretischer Physiker/Theoretische Physikerin /berufe/3008-TheoretischeR-PhysikerIn/
# Third Level Supporter (m/w) /berufe/3655-Third-Level-Supporter-%28m-w%29/
# Tibetologe/Tibetologin  /berufe/2310-Tibetologe~Tibetologin-Tibetologie-und-Buddhismuskunde/
# Ticketing Agent (m/w) /berufe/3610-Ticketing_Agent/
# TiefbauerIn /berufe/207-TiefbauerIn/
# TiefbauspezialistIn - Schwerpunkt Baumaschinenbetrieb /berufe/3519-TiefbauspezialistIn-Schwerpunkt_Baumaschinenbetrieb/
# TiefbauspezialistIn - Schwerpunkt Siedlungswasserbau /berufe/3520-TiefbauspezialistIn-Schwerpunkt_Siedlungswasserbau/
# TiefbauspezialistIn - Schwerpunkt Tunnelbautechnik /berufe/3764-TiefbauspezialistIn-Schwerpunkt_Tunnelbautechnik/
# TiefbauspezialistIn - Schwerpunkt Verkehrswegebau /berufe/3521-TiefbauspezialistIn-Schwerpunkt_Verkehrswegebau/
# TiefbautechnikerIn /berufe/2544-TiefbautechnikerIn/
# Tierarzt/-ärztin /berufe/2482-Tierarzt~Tieraerztin/
# Tierarzt/-ärztin für Tiermedizinische Forschung /berufe/2484-Tierarzt~Tieraerztin_fuer_Tiermedizinische-Forschung/
# Tierarzt/-ärztin für Veterinärverwaltung /berufe/2485-Tierarzt~Tieraerztin_fuer_Veterinaerverwaltung/
# Tierärztlich(er/e) OrdinationsassistentIn /berufe/3498-TieraerztlicheR_OrdinationsassistentIn/
# TierhändlerIn /berufe/3251-TierhaendlerIn/
# TierpflegerIn /berufe/209-TierpflegerIn/
# TiertrainerIn /berufe/3554-TiertrainerIn/
# TischlereitechnikerIn - Schwerpunkt Modell- und Formenbau /berufe/3803-TischlereitechnikerIn_-_Schwerpunkt_Modell-_und_Formenbau/
# TischlereitechnikerIn - Schwerpunkt Planung /berufe/3472-TischlereitechnikerIn_-_Schwerpunkt_Planung/
# TischlereitechnikerIn - Schwerpunkt Produktion /berufe/3473-TischlereitechnikerIn-Schwerpunkt_Produktion/
# TischlerIn - Schwerpunkt Allgemeine Tischlerei /berufe/3800-TischlerIn_-_Schwerpunkt_Allgemeine_Tischlerei/
# TischlerIn - Schwerpunkt Drechslerei /berufe/3801-TischlerIn_-_Schwerpunkt_Drechslerei/
# Tissue Engineer (m/w) /berufe/3194-Tissue-Engineer/
# ToncutterIn /berufe/3195-ToncutterIn/
# ToningenieurIn /berufe/2679-TontechnikerIn_TonmeisterIn/
# TonmeisterIn /berufe/3196-TonmeisterIn/
# TontechnikerIn /berufe/1838-TontechnikerIn/
# TourismusberaterIn /berufe/2958-TourismusberaterIn/
# Tourismuskaufmann/-frau /berufe/2145-Tourismuskaufmann-frau/
# TourismusmanagerIn /berufe/2219-TourismusmanagerIn/
# Toxikologe/Toxikologin /berufe/2476-Toxikologe~Toxikologin/
# TrafikantIn /berufe/3252-TrafikantIn/
# Trailer-ProducerIn /berufe/3197-Trailer-ProducerIn/
# TrainerIn in der Erwachsenenbildung /berufe/2873-TrainerIn-in-der-Erwachsenenbildung/
# TrainingstherapeutIn /berufe/3746-TrainingstherapeutIn/
# TransportarbeiterIn /berufe/2913-TransportarbeiterIn/
# TransportbetontechnikerIn /berufe/3038-TransportbetontechnikerIn/
# TransportmanagerIn /berufe/2514-TransportmanagerIn/
# TransportsachbearbeiterIn /berufe/1957-TransportsachbearbeiterIn/
# Treasury ManagerIn /berufe/3198-Treasury-ManagerIn/
# Trendscout (m/w) /berufe/3199-Trendscout/
# TriebfahrzeugführerIn /berufe/2914-TriebfahrzeugfuehrerIn/
# Turkologe/Turkologin /berufe/2311-Turkologe~Turkologin/
# TürsteherIn /berufe/3253-TuersteherIn/
# U-Bahn-FahrerIn /berufe/3691-U-Bahn-FahrerIn/
# ÜbersetzerIn /berufe/2289-UebersetzerIn/
# ÜbersetzerIn/DolmetscherIn im EU-Sprachdienst /berufe/2290-UebersetzerIn-und-DolmetscherIn-bei-der-EU_Sonderlaufbahn-Sprachendienst-LA/
# UhrmacherIn - ZeitmesstechnikerIn /berufe/3330-UhrmacherIn-ZeitmesstechnikerIn/
# Umwelt- und AbfallberaterIn /berufe/2923-UmweltberaterIn-AbfallberaterIn/
# UmweltanalytikerIn /berufe/3202-UmweltchemikerIn/
# UmweltbautechnikerIn /berufe/3201-UmweltbautechnikerIn/
# UmweltbeauftragteR /berufe/3867-UmweltbeauftragteR/
# UmweltberaterIn /berufe/3155-UmweltberaterIn/
# UmweltchemikerIn /berufe/1745-UmweltchemikerIn/
# WerkstoffprüferIn /berufe/2200-Werkstoffprueferin/
# WerkstofftechnikerIn /berufe/2661-WerkstofftechnikerIn/
# WerkstofftechnikerIn - Hauptmodul Werkstoffprüfung /berufe/3477-WerkstofftechnikerIn-Hauptmodul_Werkstoffpruefung/
# WerkstofftechnikerIn für biobasierte Materialien /berufe/3836-WerkstofftechnikerIn_fuer_biobasierte_Materialien/
# WerkstofftechnikerIn für Keramik /berufe/2730-WerkstofftechnikerIn_fuer_Keramik/
# WerkzeugbautechnikerIn /berufe/3674-WerkzeugbautechnikerIn/
# WindenergietechnikerIn /berufe/3659-WindenergietechnikerIn/
# WinzerIn /berufe/1948-WinzerIn/
# WirtschafterIn in Gastronomie und Hotellerie /berufe/1877-WirtschafterIn-Gastronomie-Hotellerie/
# WirtschaftsinformatikerIn /berufe/3658-WirtschaftsinformatikerIn/
# WirtschaftsingenieurIn /berufe/2115-WirtschaftsingenieurIn/
# WirtschaftsingenieurIn für Bauwesen /berufe/2589-WirtschaftsingenieurIn_fr_Bauwesen/
# WirtschaftsingenieurIn für Elektrotechnik und Elektronik /berufe/3636-WirtschaftsingenieurInfuerElektrotechnikundElektronik/
# WirtschaftsingenieurIn für Informationstechnik /berufe/3634-WirtschaftsingenieurIn_fuer_Computer_und_Informationstechnologie/
# WirtschaftsingenieurIn für Logistik /berufe/3694-WirtschaftsingenieurIn-Logistik/
# WirtschaftsingenieurIn für Maschinenbau und Fertigungstechnik /berufe/2590-WirtschaftsingenieurIn-Maschinenbau/
# WirtschaftsingenieurIn für Umwelt /berufe/3637-WirtschaftsingenieurInfuerUmwelt/
# WirtschaftsjuristIn im Bankbereich /berufe/2575-WirtschaftsjuristIn-Bankbereich/
# WirtschaftsmathematikerIn /berufe/2635-WirtschaftsmathematikerIn-Operations-Research/
# Wirtschaftspädagoge/-pädagogin /berufe/3213-Wirtschaftspaedagoge~Wirtschaftspaedagogin/
# WirtschaftsprüferIn  /berufe/2457-WirtschaftsprueferIn-SteuerberaterIn/
# WirtschaftsstatistikerIn /berufe/2625-WirtschaftsstatistikerIn/
# WirtschaftswissenschafterIn /berufe/2751-WirtschaftswissenschafterIn/
# WissenschaftlicheR bzw. künstlerischeR MitarbeiterIn /berufe/2440-WissenschaftlicheR-MitarbeiterIn_KuenstlerischeR-MitarbeiterIn/
# WissenschaftsforscherIn /berufe/2251-WissenschaftsforscherIn/
# WissenschaftsjournalistIn /berufe/2246-WissenschaftsjournalistIn/
# WissensmanagerIn /berufe/3351-WissensmanagerIn/
# Yoga-LehrerIn /berufe/3313-Yoga-LehrerIn/
# YouTuber (m/w) /berufe/3791-Youtuber/
# Zahnarzt/-ärztin /berufe/2428-Zahnarzt~Zahnaerztin/
# ZahnarztassistentIn /berufe/2802-ZahnaerztlicheR-AssistentIn/
# Zahnärztlich(er/e) FachassistentIn /berufe/3037-ZahnaerztlicheR-FachassistentIn/
# ZahntechnikerIn /berufe/230-ZahntechnikerIn/
# Zahntechnisch(er/e) FachassistentIn /berufe/3499-ZahntechischeR_FachassistentIn/
# ZeitungszustellerIn /berufe/3264-ZeitungszustellerIn/
# Zellbiologe/Zellbiologin /berufe/3295-Zellbiologe~Zellbiologin/
# ZerspanungstechnikerIn /berufe/3671-ZerspanungstechnikerIn/
# ZierpflanzengärtnerIn /berufe/1862-ZierpflanzengaertnerIn/
# ZimmereitechnikerIn /berufe/3381-ZimmereitechnikerIn/
# Zimmerer/Zimmerin /berufe/232-Zimmerer~Zimmerin/
# ZiviltechnikerIn - Architektur /berufe/2578-ZiviltechnikerIn-Architektur/
# ZiviltechnikerIn - IngenieurkonsulentIn /berufe/2576-ZiviltechnikerIn-IngenieurkonsulentIn/
# ZolldeklarantIn /berufe/1959-ZolldeklarantIn/
# Zollwachebeamter/-beamtin /berufe/3549-Zollwachebeamter~Zollwachebeamtin/
# Zoologe/Zoologin /berufe/2599-ZoologIn/
# ZugbegleiterIn /berufe/2917-ZugbegleiterIn/
# done

# %% [markdown]
# # Statistics and Outlier

# %%
# plot length of content
import matplotlib.pyplot as plt
import numpy as np

with open('data/berufslexikon.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# get the lengths of the content
lengths = [len(entry['content']) for entry in data]

# plot the lengths
plt.hist(lengths, bins=100)
plt.show()

# %%
# make a dataframe, sort by length of content and print the first 25 entries
import pandas as pd
df = pd.DataFrame(data)
# count the number of characters in the content
df['content_length'] = df['content'].str.len()
# sort by content_length
df = df.sort_values(by=['content_length'], ascending=False)
# print the first 25 entries
df
# Out:
#                           profession  \
# 84                Bankkaufmann/-frau
# 1121                SachbearbeiterIn
# 80    BankangestellteR - Back-Office
# 1275                 TeamassistentIn
# 825                 KundenbetreuerIn
# ...                              ...
# 596                     GolflehrerIn
# 1101                    ReitlehrerIn
# 1182            Souffleur/Souffleuse
# 1227                       StatistIn
# 541                    GaragenwartIn
#
#                                                     url  \
# 84    https://www.berufslexikon.at/berufe/1650-Bankk...
# 1121  https://www.berufslexikon.at/berufe/1697-Sachb...
# 80    https://www.berufslexikon.at/berufe/1649-Banka...
# 1275  https://www.berufslexikon.at/berufe/1698-Teama...
# 825   https://www.berufslexikon.at/berufe/1693-Kunde...
# ...                                                 ...
# 596   https://www.berufslexikon.at/berufe/2819-Golfl...
# 1101  https://www.berufslexikon.at/berufe/2822-Reitl...
# 1182  https://www.berufslexikon.at/berufe/3246-Souff...
# 1227  https://www.berufslexikon.at/berufe/2858-Stati...
# 541   https://www.berufslexikon.at/berufe/3226-Garag...
#
#                                                 content  content_length
# 84    \n\n\n\n\n\n\nStart | Bankkaufmann/-frau\n\n\n...          428315
# 1121  \n\n\n\n\n\n\nStart | SachbearbeiterIn\n\n\n\n...          421514
# 80    \n\n\n\n\n\n\nStart | BankangestellteR - Back-...          419602
# 1275  \n\n\n\n\n\n\nStart | TeamassistentIn\n\n\n\n ...          417379
# 825   \n\n\n\n\n\n\nStart | KundenbetreuerIn\n\n\n\n...          416867
# ...                                                 ...             ...
# 596   \n\n\n\n\n\n\nStart | GolflehrerIn\n\n\n\n Zur...            4344
# 1101  \n\n\n\n\n\n\nStart | ReitlehrerIn\n\n\n\n Zur...            4251
# 1182  \n\n\n\n\n\n\nStart | Souffleur/Souffleuse\n\n...            4082
# 1227  \n\n\n\n\n\n\nStart | StatistIn\n\n\n\n Zurück...            4052
# 541   \n\n\n\n\n\n\nStart | GaragenwartIn\n\n\n\n Zu...            3793
#
# [1403 rows x 4 columns]

# %%
import json
import re


def clean_content(content):

    content = re.sub('\n+', '\n', content)  # reduce multiple \n to one and replace with space
    # content = content.replace('\r', ' ')  # replace \r with space
    # content = content.replace('\t', ' ')  # replace \t with space
    content = re.sub(' +', ' ', content) #replace multiple spaces with one line break
    content = re.sub('\n ', '\n', content) #remove space after line break
    content = re.sub('\n+', '\n', content)  # reduce multiple \n to one and replace with space


    return content.strip()

def clean_data(data):
    cleaned_data = []
    for entry in data:
        cleaned_entry = {
            "profession": entry["profession"].strip(),
            "url": entry["url"].strip(),
            "content": clean_content(entry["content"])
        }
        cleaned_data.append(cleaned_entry)
    return cleaned_data

# %%
import json
import re

# Load the JSON file
with open('data/berufslexikon.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Define the regex patterns
pattern1 = re.compile(
    r'\nErgebnisse aus dem Ausbildungskompass:\n.*?(?=\nWeiterbildung\n|\nAufstieg und Selbstständigkeit\n|$)',
    re.DOTALL
)
pattern2 = re.compile(r"\n\n\n\n\nWeiterführende Informationen\n\n.*", re.DOTALL)
pattern3 = re.compile(r'\nAktuelles Update zu Berufsaussichten: Green Jobs\n.*?\nAusbildung\n', re.DOTALL)
pattern4 = re.compile(r'\nBeruf merken\n.*?\nTätigkeitsmerkmale\n', re.DOTALL)

# Iterate over each item and update the 'content' field using all patterns
for item in data:
    item['content'] = item['content'].replace("Start | ", "")
    item['content'] = re.sub(pattern1, '', item['content'])
    item['content'] = re.sub(pattern2, '', item['content'])
    item['content'] = re.sub(pattern3, '', item['content'])
    item['content'] = re.sub(pattern4, '', item['content'])

# Save the updated data back to the JSON file
with open('data/berufslexikon_regex.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# Clean the data
cleaned_data = clean_data(data)

# write to file and actually make a line break out of \n
with open('data/berufslexikon_regex_cleaned.json', 'w', encoding='utf-8') as f:
    json.dump(cleaned_data, f, ensure_ascii=False, indent=4)

# %%
df = pd.DataFrame(data)
# count the number of characters in the content
df['content_length'] = df['content'].str.len()
# sort by content_length
df = df.sort_values(by=['content_length'], ascending=False)
# print the first 25 entries
df
# Out:
#                                              profession  \
# 207                                  Bürokaufmann/-frau
# 680                             Industriekaufmann/-frau
# 1310  TiefbauspezialistIn - Schwerpunkt Tunnelbautec...
# 364   ElektrotechnikerIn - Hauptmodul Anlagen- und B...
# 792   KonditorIn (ZuckerbäckerIn) - Schwerpunkt Pati...
# ...                                                 ...
# 1265                                         TankwartIn
# 541                                       GaragenwartIn
# 468                                     FensterputzerIn
# 135                                       BeschließerIn
# 847                                            LadnerIn
#
#                                                     url  \
# 207   https://www.berufslexikon.at/berufe/25-Bueroka...
# 680   https://www.berufslexikon.at/berufe/97-Industr...
# 1310  https://www.berufslexikon.at/berufe/3764-Tiefb...
# 364   https://www.berufslexikon.at/berufe/3412-Elekt...
# 792   https://www.berufslexikon.at/berufe/3633-Kondi...
# ...                                                 ...
# 1265  https://www.berufslexikon.at/berufe/2812-Tankw...
# 541   https://www.berufslexikon.at/berufe/3226-Garag...
# 468   https://www.berufslexikon.at/berufe/3222-Fenst...
# 135   https://www.berufslexikon.at/berufe/2775-Besch...
# 847   https://www.berufslexikon.at/berufe/2807-Ladne...
#
#                                                 content  content_length
# 207   \n\n\n\n\n\n\nBürokaufmann/-frau\n\n\n\n Zurüc...           60783
# 680   \n\n\n\n\n\n\nIndustriekaufmann/-frau\n\n\n\n ...           41744
# 1310  \n\n\n\n\n\n\nTiefbauspezialistIn - Schwerpunk...           26465
# 364   \n\n\n\n\n\n\nElektrotechnikerIn - Hauptmodul ...           26299
# 792   \n\n\n\n\n\n\nKonditorIn (ZuckerbäckerIn) - Sc...           25744
# ...                                                 ...             ...
# 1265  \n\n\n\n\n\n\nTankwartIn\n\n\n\n Zurück\n\n\n\...            2060
# 541   \n\n\n\n\n\n\nGaragenwartIn\n\n\n\n Zurück\n\n...            2020
# 468   \n\n\n\n\n\n\nFensterputzerIn\n\n\n\n Zurück\n...            1987
# 135   \n\n\n\n\n\n\nBeschließerIn\n\n\n\n Zurück\n\n...            1957
# 847   \n\n\n\n\n\n\nLadnerIn\n\n\n\n Zurück\n\n\n\n\...            1897
#
# [1403 rows x 4 columns]
